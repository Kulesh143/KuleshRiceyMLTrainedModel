# %%
# # import numpy as np
# # import pandas as pd
# # import os
# # from google.colab import drive
# # from sklearn.model_selection import train_test_split
# # from tensorflow.keras.preprocessing.image import ImageDataGenerator
# # from tensorflow.keras import layers, models, optimizers, callbacks
# # import matplotlib.pyplot as plt
# # import tensorflow as tf
# # from google.colab import files

# # # Mount Google Drive
# # drive.mount('/content/drive')

# # # Data Directory Setup
# # data_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients"
# # os.listdir(data_dir)

# # nutrient = ["Nitrogen(N)", "Potassium(K)", "Phosphorus(P)"]
# # nutrient_dict = {i: os.path.join(data_dir, i) for i in nutrient}

# # # Function to count images in directories
# # def count_image_dir(nutrient_dict):
# #     return {i: len(os.listdir(nutrient_dict[i])) for i in nutrient_dict}

# # count_dict = count_image_dir(nutrient_dict)

# # # Adjust DataFrame to include healthy images and dummy unhealthy samples
# # def create_df(nutrient_dict):
# #     file_list = []
# #     # Add healthy images
# #     for nutrient_name, nutrient_path in nutrient_dict.items():
# #         file_list += list(map(lambda x: [os.path.join(nutrient_path, x), "Healthy"], os.listdir(nutrient_path)))

# #     # Add dummy 'Unhealthy' samples (use the same paths for simplicity)
# #     for i in range(50):  # Let's assume we add 50 dummy samples
# #         file_list.append([file_list[i % len(file_list)][0], "Unhealthy"])  # Duplicating image paths

# #     return pd.DataFrame(file_list, columns=["filepaths", "labels"])

# # # Create DataFrame with healthy images and dummy unhealthy samples
# # tb_df = create_df(nutrient_dict)

# # # Display the DataFrame
# # print(tb_df.head())
# import numpy as np
# import pandas as pd
# import os
# import shutil  # Import shutil for file operations
# from google.colab import drive
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras import layers, models, optimizers, callbacks
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from google.colab import files

# # Mount Google Drive
# drive.mount('/content/drive')

# # Data Directory Setup
# data_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients"
# os.listdir(data_dir)

# nutrient = ["Nitrogen(N)", "Potassium(K)", "Phosphorus(P)"]
# nutrient_dict = {i: os.path.join(data_dir, i) for i in nutrient}

# # Function to count images in directories
# def count_image_dir(nutrient_dict):
#     return {i: len(os.listdir(nutrient_dict[i])) for i in nutrient_dict}

# count_dict = count_image_dir(nutrient_dict)

# # Adjust DataFrame to include healthy images and dummy unhealthy samples
# def create_df(nutrient_dict):
#     file_list = []
#     # Add healthy images
#     for nutrient_name, nutrient_path in nutrient_dict.items():
#         file_list += list(map(lambda x: [os.path.join(nutrient_path, x), "Healthy"], os.listdir(nutrient_path)))

#     # Add dummy 'Unhealthy' samples (use the same paths for simplicity)
#     for i in range(50):  # Let's assume we add 50 dummy samples
#         file_list.append([file_list[i % len(file_list)][0], "Unhealthy"])  # Duplicating image paths

#     return pd.DataFrame(file_list, columns=["filepaths", "labels"])

# # Create DataFrame with healthy images and dummy unhealthy samples
# tb_df = create_df(nutrient_dict)

# # Create a new directory for Unhealthy samples
# unhealthy_dir = os.path.join(data_dir, 'Unhealthy')
# os.makedirs(unhealthy_dir, exist_ok=True)  # Create the directory if it doesn't exist

# # Copy dummy unhealthy samples to the new Unhealthy directory
# for i in range(50):  # Assuming we have added 50 dummy samples
#     # Get the path of the dummy "Unhealthy" image
#     dummy_image_path = tb_df['filepaths'][len(nutrient_dict) + i % len(nutrient_dict)].replace("Healthy", "Unhealthy")

#     # Copy the image to the Unhealthy directory
#     shutil.copy(tb_df['filepaths'][i % len(tb_df)], unhealthy_dir)

# # Display the DataFrame
# print(tb_df.head())
# import numpy as np
# import pandas as pd
# import os
# import shutil  # Import shutil for file operations
# from google.colab import drive
# from sklearn.model_selection import train_test_split
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras import layers, models, optimizers, callbacks
# import matplotlib.pyplot as plt
# import tensorflow as tf
# from google.colab import files

# # Mount Google Drive
# drive.mount('/content/drive')

# # Data Directory Setup
# data_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients"
# os.listdir(data_dir)

# nutrient = ["Nitrogen(N)", "Potassium(K)", "Phosphorus(P)"]
# nutrient_dict = {i: os.path.join(data_dir, i) for i in nutrient}

# # Function to count images in directories
# def count_image_dir(nutrient_dict):
#     return {i: len(os.listdir(nutrient_dict[i])) for i in nutrient_dict}

# count_dict = count_image_dir(nutrient_dict)

# # Adjust DataFrame to include healthy images and dummy unhealthy samples
# def create_df(nutrient_dict):
#     file_list = []
#     # Add healthy images
#     for nutrient_name, nutrient_path in nutrient_dict.items():
#         file_list += list(map(lambda x: [os.path.join(nutrient_path, x), "Healthy"], os.listdir(nutrient_path)))

#     # Add dummy 'Unhealthy' samples (use the same paths for simplicity)
#     for i in range(50):  # Let's assume we add 50 dummy samples
#         file_list.append([file_list[i % len(file_list)][0], "Unhealthy"])  # Duplicating image paths

#     return pd.DataFrame(file_list, columns=["filepaths", "labels"])

# # Create DataFrame with healthy images and dummy unhealthy samples
# com_df = create_df(nutrient_dict)

# # Create a new directory for Unhealthy samples if not already created
# unhealthy_dir = os.path.join(data_dir, 'Unhealthy')
# os.makedirs(unhealthy_dir, exist_ok=True)  # Create the directory if it doesn't exist

# # Copy dummy unhealthy samples to the new Unhealthy directory
# for i in range(50):  # Assuming we have added 50 dummy samples
#     # Get the path of the dummy "Unhealthy" image
#     dummy_image_path = com_df['filepaths'][len(nutrient_dict) + i % len(nutrient_dict)].replace("Healthy", "Unhealthy")

#     # Copy the image to the Unhealthy directory
#     shutil.copy(com_df['filepaths'][i % len(tb_df)], unhealthy_dir)

# # Load and verify the Unhealthy images from a different directory
# unhealthy_images_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/unhealthy_rice_plants"
# unhealthy_files = os.listdir(unhealthy_images_dir)

# # Display the unhealthy images and their labels
# unhealthy_df = pd.DataFrame(unhealthy_files, columns=["filepaths"])
# unhealthy_df['labels'] = "Unhealthy"  # Label all as unhealthy

# # Display the DataFrame for unhealthy images
# print(unhealthy_df.head())

# # If you want to combine with the main DataFrame
# tb_df = pd.concat([com_df, unhealthy_df], ignore_index=True)
# print(tb_df.head())
import numpy as np
import pandas as pd
import os
import shutil  # Import shutil for file operations
from google.colab import drive
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models, optimizers, callbacks
import matplotlib.pyplot as plt
import tensorflow as tf
from google.colab import files

# Mount Google Drive
drive.mount('/content/drive')

# Data Directory Setup
data_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients"
os.listdir(data_dir)

# Define nutrient categories (for healthy images)
nutrient = ["Nitrogen(N)", "Potassium(K)", "Phosphorus(P)"]
nutrient_dict = {i: os.path.join(data_dir, i) for i in nutrient}

# Function to count images in directories
def count_image_dir(nutrient_dict):
    return {i: len(os.listdir(nutrient_dict[i])) for i in nutrient_dict}

count_dict = count_image_dir(nutrient_dict)

# Adjust DataFrame to include healthy images from the nutrient_dict
def create_df(nutrient_dict):
    file_list = []
    # Add healthy images
    for nutrient_name, nutrient_path in nutrient_dict.items():
        file_list += list(map(lambda x: [os.path.join(nutrient_path, x), "Healthy"], os.listdir(nutrient_path)))

    return pd.DataFrame(file_list, columns=["filepaths", "labels"])

# Create DataFrame with healthy images
healthy_df = create_df(nutrient_dict)

# Load and verify the Unhealthy images from the 'unhealthy_rice_plants' directory
unhealthy_images_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/Unhealthy/"
unhealthy_files = os.listdir(unhealthy_images_dir)

# Create a DataFrame for unhealthy images
unhealthy_df = pd.DataFrame(list(map(lambda x: [os.path.join(unhealthy_images_dir, x), "Unhealthy"], unhealthy_files)),
                            columns=["filepaths", "labels"])

# Combine healthy and unhealthy DataFrames
tb_df = pd.concat([healthy_df, unhealthy_df], ignore_index=True)

# Display the combined DataFrame
print(tb_df.head())

# Optional: Count the number of healthy and unhealthy samples
print("Sample counts by label:")
print(tb_df['labels'].value_counts())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                            filepaths   labels
# 0  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 1  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 2  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 3  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 4  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# Sample counts by label:
# labels
# Healthy      1156
# Unhealthy      42
# Name: count, dtype: int64

# %%
tb_df.columns
# Out:
# Index(['filepaths', 'labels'], dtype='object')

# %%
tb_df.shape
# Out:
# (1198, 2)

# %%
tb_df
# Out:
#                                               filepaths     labels
# 0     /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
# 1     /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
# 2     /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
# 3     /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
# 4     /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
# ...                                                 ...        ...
# 1193  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
# 1194  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
# 1195  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
# 1196  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
# 1197  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
#
# [1198 rows x 2 columns]

# %%
tb_df.dtypes
# Out:
# filepaths    object
# labels       object
# dtype: object

# %%
# Check the distribution of labels
print(tb_df['labels'].value_counts())
# Out:
# labels
# Healthy      1156
# Unhealthy      42
# Name: count, dtype: int64

# %%
# Checking the total sum of the missing values in every column to see if they are there
missing_values_in_columns_sum = tb_df.isna().sum()

# Genearte the total percentage of missing values if they are there
total_no_of_rows = tb_df.shape[0]
missing_values_percentage = (missing_values_in_columns_sum / total_no_of_rows) * 100

# taking the data type of the columns in the dataset
datatype_column = tb_df.dtypes

# Making a DataFrame to show and display the results
missing_info_in_dataset = pd.DataFrame({
    'Data Type': datatype_column,
    'Missing Values': missing_values_in_columns_sum,
    'Percentage Missing (%)': missing_values_percentage
})

# Now here the missing values sum and percentage is displayed
print(missing_info_in_dataset)
# Out:
#           Data Type  Missing Values  Percentage Missing (%)
# filepaths    object               0                     0.0
# labels       object               0                     0.0

# %%
import os
import cv2
import numpy as np
from PIL import Image

# Data Directory Setup
data_dir = r"/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients"
nutrient = ["Nitrogen(N)", "Potassium(K)", "Phosphorus(P)"]
nutrient_dict = {i: os.path.join(data_dir, i) for i in nutrient}

# Path for the Unhealthy folder
unhealthy_directory = r"/content/drive/My Drive/PaddyLeafDeficiency/Unhealthy"

def is_corrupted(image_path):
    try:
        img = Image.open(image_path)
        img.verify()  # Check if image is corrupt
        return False
    except (IOError, SyntaxError):
        return True

def resize_image(image, size=(128, 128)):
    return cv2.resize(image, size)

def normalize_image(image):
    return image / 255.0  # Scale pixel values to [0, 1]

def clean_image_dataset(input_dir):
    seen_images = set()  # To track duplicates
    for filename in os.listdir(input_dir):
        if filename.endswith(('.jpg', '.jpeg', '.JPG')):
            image_path = os.path.join(input_dir, filename)

            # Step 1: Remove corrupted images
            if is_corrupted(image_path):
                print(f"Corrupted image: {filename}")
                continue

            # Step 2: Read the image
            image = cv2.imread(image_path)
            if image is None:
                print(f"Unable to read image: {filename}. Skipping.")
                continue

            # Step 3: Resize image
            image = resize_image(image)

            # Step 4: Normalize image
            image = normalize_image(image)

            # Step 5: Remove duplicates
            image_hash = hash(image.tobytes())
            if image_hash in seen_images:
                print(f"Duplicate image: {filename}. Skipping.")
                continue
            seen_images.add(image_hash)

            # Step 6: Create a new filename with the pattern 'cleaned_<original_filename>'
            new_filename = f"cleaned_{filename}"
            output_path = os.path.join(input_dir, new_filename)

            # Save the cleaned image, overwriting with the new pattern
            if not cv2.imwrite(output_path, (image * 255).astype(np.uint8)):
                print(f"Failed to save image: {new_filename}")
                continue

            # Optionally remove the original image to avoid duplicates if needed
            try:
                os.remove(image_path)
                print(f"Original image {filename} removed.")
            except Exception as e:
                print(f"Error removing image {filename}: {e}")

# Clean images for each nutrient category and save them back to the same folder
for nutrient_name, nutrient_path in nutrient_dict.items():
    clean_image_dataset(nutrient_path)

# Clean images in the Unhealthy directory and save them back to the same folder
clean_image_dataset(unhealthy_directory)
# Out:
# Original image cleaned_cleaned_untitled-1.JPG removed.
# Original image cleaned_cleaned_untitled-10.JPG removed.
# Original image cleaned_cleaned_untitled-100.JPG removed.
# Original image cleaned_cleaned_untitled-102.JPG removed.
# Original image cleaned_cleaned_untitled-101.JPG removed.
# Original image cleaned_cleaned_untitled-124.JPG removed.
# Original image cleaned_cleaned_untitled-129.JPG removed.
# Original image cleaned_cleaned_untitled-105.JPG removed.
# Original image cleaned_cleaned_untitled-11.JPG removed.
# Original image cleaned_cleaned_untitled-123.JPG removed.
# Original image cleaned_cleaned_untitled-104.JPG removed.
# Original image cleaned_cleaned_untitled-125.JPG removed.
# Original image cleaned_cleaned_untitled-108.JPG removed.
# Original image cleaned_cleaned_untitled-121.JPG removed.
# Original image cleaned_cleaned_untitled-106.JPG removed.
# Original image cleaned_cleaned_untitled-120.JPG removed.
# Original image cleaned_cleaned_untitled-114.JPG removed.
# Original image cleaned_cleaned_untitled-103.JPG removed.
# Original image cleaned_cleaned_untitled-115.JPG removed.
# Original image cleaned_cleaned_untitled-118.JPG removed.
# Original image cleaned_cleaned_untitled-109.JPG removed.
# Original image cleaned_cleaned_untitled-112.JPG removed.
# Original image cleaned_cleaned_untitled-126.JPG removed.
# Original image cleaned_cleaned_untitled-110.JPG removed.
# Original image cleaned_cleaned_untitled-127.JPG removed.
# Original image cleaned_cleaned_untitled-128.JPG removed.
# Original image cleaned_cleaned_untitled-107.JPG removed.
# Original image cleaned_cleaned_untitled-117.JPG removed.
# Original image cleaned_cleaned_untitled-12.JPG removed.
# Original image cleaned_cleaned_untitled-122.JPG removed.
# Original image cleaned_cleaned_untitled-111.JPG removed.
# Original image cleaned_cleaned_untitled-119.JPG removed.
# Original image cleaned_cleaned_untitled-116.JPG removed.
# Original image cleaned_cleaned_untitled-113.JPG removed.
# Original image cleaned_cleaned_untitled-153.JPG removed.
# Original image cleaned_cleaned_untitled-154.JPG removed.
# Original image cleaned_cleaned_untitled-158.JPG removed.
# Original image cleaned_cleaned_untitled-15.JPG removed.
# Original image cleaned_cleaned_untitled-13.JPG removed.
# Original image cleaned_cleaned_untitled-138.JPG removed.
# Original image cleaned_cleaned_untitled-144.JPG removed.
# Original image cleaned_cleaned_untitled-131.JPG removed.
# Original image cleaned_cleaned_untitled-137.JPG removed.
# Original image cleaned_cleaned_untitled-143.JPG removed.
# Original image cleaned_cleaned_untitled-149.JPG removed.
# Original image cleaned_cleaned_untitled-130.JPG removed.
# Original image cleaned_cleaned_untitled-133.JPG removed.
# Original image cleaned_cleaned_untitled-155.JPG removed.
# Original image cleaned_cleaned_untitled-142.JPG removed.
# Original image cleaned_cleaned_untitled-139.JPG removed.
# Original image cleaned_cleaned_untitled-150.JPG removed.
# Original image cleaned_cleaned_untitled-146.JPG removed.
# Original image cleaned_cleaned_untitled-136.JPG removed.
# Original image cleaned_cleaned_untitled-156.JPG removed.
# Original image cleaned_cleaned_untitled-135.JPG removed.
# Original image cleaned_cleaned_untitled-140.JPG removed.
# Original image cleaned_cleaned_untitled-147.JPG removed.
# Original image cleaned_cleaned_untitled-148.JPG removed.
# Original image cleaned_cleaned_untitled-141.JPG removed.
# Original image cleaned_cleaned_untitled-145.JPG removed.
# Original image cleaned_cleaned_untitled-151.JPG removed.
# Original image cleaned_cleaned_untitled-134.JPG removed.
# Original image cleaned_cleaned_untitled-14.JPG removed.
# Original image cleaned_cleaned_untitled-152.JPG removed.
# Original image cleaned_cleaned_untitled-157.JPG removed.
# Original image cleaned_cleaned_untitled-132.JPG removed.
# Original image cleaned_cleaned_untitled-174.JPG removed.
# Original image cleaned_cleaned_untitled-160.JPG removed.
# Original image cleaned_cleaned_untitled-183.JPG removed.
# Original image cleaned_cleaned_untitled-161.JPG removed.
# Original image cleaned_cleaned_untitled-17.JPG removed.
# Original image cleaned_cleaned_untitled-162.JPG removed.
# Original image cleaned_cleaned_untitled-173.JPG removed.
# Original image cleaned_cleaned_untitled-168.JPG removed.
# Original image cleaned_cleaned_untitled-182.JPG removed.
# Original image cleaned_cleaned_untitled-167.JPG removed.
# Original image cleaned_cleaned_untitled-169.JPG removed.
# Original image cleaned_cleaned_untitled-178.JPG removed.
# Original image cleaned_cleaned_untitled-181.JPG removed.
# Original image cleaned_cleaned_untitled-164.JPG removed.
# Original image cleaned_cleaned_untitled-163.JPG removed.
# Original image cleaned_cleaned_untitled-176.JPG removed.
# Original image cleaned_cleaned_untitled-175.JPG removed.
# Original image cleaned_cleaned_untitled-172.JPG removed.
# Original image cleaned_cleaned_untitled-159.JPG removed.
# Original image cleaned_cleaned_untitled-171.JPG removed.
# Original image cleaned_cleaned_untitled-179.JPG removed.
# Original image cleaned_cleaned_untitled-177.JPG removed.
# Original image cleaned_cleaned_untitled-166.JPG removed.
# Original image cleaned_cleaned_untitled-18.JPG removed.
# Original image cleaned_cleaned_untitled-165.JPG removed.
# Original image cleaned_cleaned_untitled-180.JPG removed.
# Original image cleaned_cleaned_untitled-16.JPG removed.
# Original image cleaned_cleaned_untitled-170.JPG removed.
# Original image cleaned_cleaned_untitled-203.JPG removed.
# Original image cleaned_cleaned_untitled-185.JPG removed.
# Original image cleaned_cleaned_untitled-194.JPG removed.
# Original image cleaned_cleaned_untitled-204.JPG removed.
# Original image cleaned_cleaned_untitled-209.JPG removed.
# Original image cleaned_cleaned_untitled-198.JPG removed.
# Original image cleaned_cleaned_untitled-2.JPG removed.
# Original image cleaned_cleaned_untitled-208.JPG removed.
# Original image cleaned_cleaned_untitled-187.JPG removed.
# Original image cleaned_cleaned_untitled-20.JPG removed.
# Original image cleaned_cleaned_untitled-193.JPG removed.
# Original image cleaned_cleaned_untitled-197.JPG removed.
# Original image cleaned_cleaned_untitled-188.JPG removed.
# Original image cleaned_cleaned_untitled-186.JPG removed.
# Original image cleaned_cleaned_untitled-189.JPG removed.
# Original image cleaned_cleaned_untitled-195.JPG removed.
# Original image cleaned_cleaned_untitled-207.JPG removed.
# Original image cleaned_cleaned_untitled-190.JPG removed.
# Original image cleaned_cleaned_untitled-196.JPG removed.
# Original image cleaned_cleaned_untitled-184.JPG removed.
# Original image cleaned_cleaned_untitled-205.JPG removed.
# Original image cleaned_cleaned_untitled-199.JPG removed.
# Original image cleaned_cleaned_untitled-19.JPG removed.
# Original image cleaned_cleaned_untitled-21.JPG removed.
# Original image cleaned_cleaned_untitled-202.JPG removed.
# Original image cleaned_cleaned_untitled-191.JPG removed.
# Original image cleaned_cleaned_untitled-206.JPG removed.
# Original image cleaned_cleaned_untitled-192.JPG removed.
# Original image cleaned_cleaned_untitled-201.JPG removed.
# Original image cleaned_cleaned_untitled-200.JPG removed.
# Original image cleaned_cleaned_untitled-231.JPG removed.
# Original image cleaned_cleaned_untitled-230.JPG removed.
# Original image cleaned_cleaned_untitled-215.JPG removed.
# Original image cleaned_cleaned_untitled-211.JPG removed.
# Original image cleaned_cleaned_untitled-229.JPG removed.
# Original image cleaned_cleaned_untitled-217.JPG removed.
# Original image cleaned_cleaned_untitled-224.JPG removed.
# Original image cleaned_cleaned_untitled-237.JPG removed.
# Original image cleaned_cleaned_untitled-22.JPG removed.
# Original image cleaned_cleaned_untitled-222.JPG removed.
# Original image cleaned_cleaned_untitled-233.JPG removed.
# Original image cleaned_cleaned_untitled-23.JPG removed.
# Original image cleaned_cleaned_untitled-223.JPG removed.
# Original image cleaned_cleaned_untitled-221.JPG removed.
# Original image cleaned_cleaned_untitled-213.JPG removed.
# Original image cleaned_cleaned_untitled-226.JPG removed.
# Original image cleaned_cleaned_untitled-216.JPG removed.
# Original image cleaned_cleaned_untitled-234.JPG removed.
# Original image cleaned_cleaned_untitled-228.JPG removed.
# Original image cleaned_cleaned_untitled-227.JPG removed.
# Original image cleaned_cleaned_untitled-210.JPG removed.
# Original image cleaned_cleaned_untitled-218.JPG removed.
# Original image cleaned_cleaned_untitled-236.JPG removed.
# Original image cleaned_cleaned_untitled-220.JPG removed.
# Original image cleaned_cleaned_untitled-214.JPG removed.
# Original image cleaned_cleaned_untitled-238.JPG removed.
# Original image cleaned_cleaned_untitled-212.JPG removed.
# Original image cleaned_cleaned_untitled-232.JPG removed.
# Original image cleaned_cleaned_untitled-219.JPG removed.
# Original image cleaned_cleaned_untitled-235.JPG removed.
# Original image cleaned_cleaned_untitled-225.JPG removed.
# Original image cleaned_cleaned_untitled-26.JPG removed.
# Original image cleaned_cleaned_untitled-242.JPG removed.
# Original image cleaned_cleaned_untitled-255.JPG removed.
# Original image cleaned_cleaned_untitled-247.JPG removed.
# Original image cleaned_cleaned_untitled-266.JPG removed.
# Original image cleaned_cleaned_untitled-251.JPG removed.
# Original image cleaned_cleaned_untitled-239.JPG removed.
# Original image cleaned_cleaned_untitled-269.JPG removed.
# Original image cleaned_cleaned_untitled-261.JPG removed.
# Original image cleaned_cleaned_untitled-24.JPG removed.
# Original image cleaned_cleaned_untitled-260.JPG removed.
# Original image cleaned_cleaned_untitled-259.JPG removed.
# Original image cleaned_cleaned_untitled-243.JPG removed.
# Original image cleaned_cleaned_untitled-262.JPG removed.
# Original image cleaned_cleaned_untitled-244.JPG removed.
# Original image cleaned_cleaned_untitled-267.JPG removed.
# Original image cleaned_cleaned_untitled-264.JPG removed.
# Original image cleaned_cleaned_untitled-265.JPG removed.
# Original image cleaned_cleaned_untitled-240.JPG removed.
# Original image cleaned_cleaned_untitled-263.JPG removed.
# Original image cleaned_cleaned_untitled-246.JPG removed.
# Original image cleaned_cleaned_untitled-254.JPG removed.
# Original image cleaned_cleaned_untitled-256.JPG removed.
# Original image cleaned_cleaned_untitled-245.JPG removed.
# Original image cleaned_cleaned_untitled-241.JPG removed.
# Original image cleaned_cleaned_untitled-268.JPG removed.
# Original image cleaned_cleaned_untitled-252.JPG removed.
# Original image cleaned_cleaned_untitled-249.JPG removed.
# Original image cleaned_cleaned_untitled-253.JPG removed.
# Original image cleaned_cleaned_untitled-258.JPG removed.
# Original image cleaned_cleaned_untitled-25.JPG removed.
# Original image cleaned_cleaned_untitled-257.JPG removed.
# Original image cleaned_cleaned_untitled-248.JPG removed.
# Original image cleaned_cleaned_untitled-250.JPG removed.
# Original image cleaned_cleaned_untitled-295.JPG removed.
# Original image cleaned_cleaned_untitled-276.JPG removed.
# Original image cleaned_cleaned_untitled-284.JPG removed.
# Original image cleaned_cleaned_untitled-272.JPG removed.
# Original image cleaned_cleaned_untitled-285.JPG removed.
# Original image cleaned_cleaned_untitled-282.JPG removed.
# Original image cleaned_cleaned_untitled-291.JPG removed.
# Original image cleaned_cleaned_untitled-292.JPG removed.
# Original image cleaned_cleaned_untitled-277.JPG removed.
# Original image cleaned_cleaned_untitled-293.JPG removed.
# Original image cleaned_cleaned_untitled-29.JPG removed.
# Original image cleaned_cleaned_untitled-296.JPG removed.
# Original image cleaned_cleaned_untitled-270.JPG removed.
# Original image cleaned_cleaned_untitled-286.JPG removed.
# Original image cleaned_cleaned_untitled-294.JPG removed.
# Original image cleaned_cleaned_untitled-283.JPG removed.
# Original image cleaned_cleaned_untitled-27.JPG removed.
# Original image cleaned_cleaned_untitled-274.JPG removed.
# Original image cleaned_cleaned_untitled-281.JPG removed.
# Original image cleaned_cleaned_untitled-297.JPG removed.
# Original image cleaned_cleaned_untitled-288.JPG removed.
# Original image cleaned_cleaned_untitled-279.JPG removed.
# Original image cleaned_cleaned_untitled-290.JPG removed.
# Original image cleaned_cleaned_untitled-280.JPG removed.
# Original image cleaned_cleaned_untitled-278.JPG removed.
# Original image cleaned_cleaned_untitled-273.JPG removed.
# Original image cleaned_cleaned_untitled-289.JPG removed.
# Original image cleaned_cleaned_untitled-298.JPG removed.
# Original image cleaned_cleaned_untitled-287.JPG removed.
# Original image cleaned_cleaned_untitled-271.JPG removed.
# Original image cleaned_cleaned_untitled-28.JPG removed.
# Original image cleaned_cleaned_untitled-275.JPG removed.
# Original image cleaned_cleaned_untitled-316.JPG removed.
# Original image cleaned_cleaned_untitled-303.JPG removed.
# Original image cleaned_cleaned_untitled-304.JPG removed.
# Original image cleaned_cleaned_untitled-310.JPG removed.
# Original image cleaned_cleaned_untitled-317.JPG removed.
# Original image cleaned_cleaned_untitled-30.JPG removed.
# Original image cleaned_cleaned_untitled-301.JPG removed.
# Original image cleaned_cleaned_untitled-318.JPG removed.
# Original image cleaned_cleaned_untitled-323.JPG removed.
# Original image cleaned_cleaned_untitled-311.JPG removed.
# Original image cleaned_cleaned_untitled-3.JPG removed.
# Original image cleaned_cleaned_untitled-324.JPG removed.
# Original image cleaned_cleaned_untitled-314.JPG removed.
# Original image cleaned_cleaned_untitled-299.JPG removed.
# Original image cleaned_cleaned_untitled-321.JPG removed.
# Original image cleaned_cleaned_untitled-319.JPG removed.
# Original image cleaned_cleaned_untitled-320.JPG removed.
# Original image cleaned_cleaned_untitled-313.JPG removed.
# Original image cleaned_cleaned_untitled-306.JPG removed.
# Original image cleaned_cleaned_untitled-308.JPG removed.
# Original image cleaned_cleaned_untitled-307.JPG removed.
# Original image cleaned_cleaned_untitled-312.JPG removed.
# Original image cleaned_cleaned_untitled-305.JPG removed.
# Original image cleaned_cleaned_untitled-32.JPG removed.
# Original image cleaned_cleaned_untitled-325.JPG removed.
# Original image cleaned_cleaned_untitled-309.JPG removed.
# Original image cleaned_cleaned_untitled-315.JPG removed.
# Original image cleaned_cleaned_untitled-302.JPG removed.
# Original image cleaned_cleaned_untitled-322.JPG removed.
# Original image cleaned_cleaned_untitled-31.JPG removed.
# Original image cleaned_cleaned_untitled-300.JPG removed.
# Original image cleaned_cleaned_untitled-330.JPG removed.
# Original image cleaned_cleaned_untitled-332.JPG removed.
# Original image cleaned_cleaned_untitled-34.JPG removed.
# Original image cleaned_cleaned_untitled-340.JPG removed.
# Original image cleaned_cleaned_untitled-326.JPG removed.
# Original image cleaned_cleaned_untitled-333.JPG removed.
# Original image cleaned_cleaned_untitled-33.JPG removed.
# Original image cleaned_cleaned_untitled-337.JPG removed.
# Original image cleaned_cleaned_untitled-342.JPG removed.
# Original image cleaned_cleaned_untitled-351.JPG removed.
# Original image cleaned_cleaned_untitled-346.JPG removed.
# Original image cleaned_cleaned_untitled-349.JPG removed.
# Original image cleaned_cleaned_untitled-345.JPG removed.
# Original image cleaned_cleaned_untitled-343.JPG removed.
# Original image cleaned_cleaned_untitled-331.JPG removed.
# Original image cleaned_cleaned_untitled-328.JPG removed.
# Original image cleaned_cleaned_untitled-352.JPG removed.
# Original image cleaned_cleaned_untitled-339.JPG removed.
# Original image cleaned_cleaned_untitled-350.JPG removed.
# Original image cleaned_cleaned_untitled-344.JPG removed.
# Original image cleaned_cleaned_untitled-35.JPG removed.
# Original image cleaned_cleaned_untitled-336.JPG removed.
# Original image cleaned_cleaned_untitled-335.JPG removed.
# Original image cleaned_cleaned_untitled-329.JPG removed.
# Original image cleaned_cleaned_untitled-347.JPG removed.
# Original image cleaned_cleaned_untitled-334.JPG removed.
# Original image cleaned_cleaned_untitled-353.JPG removed.
# Original image cleaned_cleaned_untitled-341.JPG removed.
# Original image cleaned_cleaned_untitled-348.JPG removed.
# Original image cleaned_cleaned_untitled-327.JPG removed.
# Original image cleaned_cleaned_untitled-338.JPG removed.
# Original image cleaned_cleaned_untitled-363.JPG removed.
# Original image cleaned_cleaned_untitled-381.JPG removed.
# Original image cleaned_cleaned_untitled-368.JPG removed.
# Original image cleaned_cleaned_untitled-36.JPG removed.
# Original image cleaned_cleaned_untitled-362.JPG removed.
# Original image cleaned_cleaned_untitled-356.JPG removed.
# Original image cleaned_cleaned_untitled-377.JPG removed.
# Original image cleaned_cleaned_untitled-358.JPG removed.
# Original image cleaned_cleaned_untitled-355.JPG removed.
# Original image cleaned_cleaned_untitled-366.JPG removed.
# Original image cleaned_cleaned_untitled-380.JPG removed.
# Original image cleaned_cleaned_untitled-379.JPG removed.
# Original image cleaned_cleaned_untitled-376.JPG removed.
# Original image cleaned_cleaned_untitled-374.JPG removed.
# Original image cleaned_cleaned_untitled-38.JPG removed.
# Original image cleaned_cleaned_untitled-37.JPG removed.
# Original image cleaned_cleaned_untitled-375.JPG removed.
# Original image cleaned_cleaned_untitled-360.JPG removed.
# Original image cleaned_cleaned_untitled-354.JPG removed.
# Original image cleaned_cleaned_untitled-371.JPG removed.
# Original image cleaned_cleaned_untitled-357.JPG removed.
# Original image cleaned_cleaned_untitled-372.JPG removed.
# Original image cleaned_cleaned_untitled-359.JPG removed.
# Original image cleaned_cleaned_untitled-365.JPG removed.
# Original image cleaned_cleaned_untitled-373.JPG removed.
# Original image cleaned_cleaned_untitled-364.JPG removed.
# Original image cleaned_cleaned_untitled-367.JPG removed.
# Original image cleaned_cleaned_untitled-382.JPG removed.
# Original image cleaned_cleaned_untitled-369.JPG removed.
# Original image cleaned_cleaned_untitled-370.JPG removed.
# Original image cleaned_cleaned_untitled-361.JPG removed.
# Original image cleaned_cleaned_untitled-378.JPG removed.
# Original image cleaned_cleaned_untitled-390.JPG removed.
# Original image cleaned_cleaned_untitled-383.JPG removed.
# Original image cleaned_cleaned_untitled-406.JPG removed.
# Original image cleaned_cleaned_untitled-400.JPG removed.
# Original image cleaned_cleaned_untitled-411.JPG removed.
# Original image cleaned_cleaned_untitled-401.JPG removed.
# Original image cleaned_cleaned_untitled-393.JPG removed.
# Original image cleaned_cleaned_untitled-392.JPG removed.
# Original image cleaned_cleaned_untitled-407.JPG removed.
# Original image cleaned_cleaned_untitled-408.JPG removed.
# Original image cleaned_cleaned_untitled-398.JPG removed.
# Original image cleaned_cleaned_untitled-395.JPG removed.
# Original image cleaned_cleaned_untitled-40.JPG removed.
# Original image cleaned_cleaned_untitled-388.JPG removed.
# Original image cleaned_cleaned_untitled-410.JPG removed.
# Original image cleaned_cleaned_untitled-394.JPG removed.
# Original image cleaned_cleaned_untitled-405.JPG removed.
# Original image cleaned_cleaned_untitled-397.JPG removed.
# Original image cleaned_cleaned_untitled-403.JPG removed.
# Original image cleaned_cleaned_untitled-4.JPG removed.
# Original image cleaned_cleaned_untitled-396.JPG removed.
# Original image cleaned_cleaned_untitled-387.JPG removed.
# Original image cleaned_cleaned_untitled-402.JPG removed.
# Original image cleaned_cleaned_untitled-389.JPG removed.
# Original image cleaned_cleaned_untitled-39.JPG removed.
# Original image cleaned_cleaned_untitled-41.JPG removed.
# Original image cleaned_cleaned_untitled-409.JPG removed.
# Original image cleaned_cleaned_untitled-404.JPG removed.
# Original image cleaned_cleaned_untitled-385.JPG removed.
# Original image cleaned_cleaned_untitled-391.JPG removed.
# Original image cleaned_cleaned_untitled-386.JPG removed.
# Original image cleaned_cleaned_untitled-384.JPG removed.
# Original image cleaned_cleaned_untitled-399.JPG removed.
# Original image cleaned_cleaned_untitled-428.JPG removed.
# Original image cleaned_cleaned_untitled-438.JPG removed.
# Original image cleaned_cleaned_untitled-413.JPG removed.
# Original image cleaned_cleaned_untitled-430.JPG removed.
# Original image cleaned_cleaned_untitled-412.JPG removed.
# Original image cleaned_cleaned_untitled-426.JPG removed.
# Original image cleaned_cleaned_untitled-436.JPG removed.
# Original image cleaned_cleaned_untitled-432.JPG removed.
# Original image cleaned_cleaned_untitled-437.JPG removed.
# Original image cleaned_cleaned_untitled-422.JPG removed.
# Original image cleaned_cleaned_untitled-425.JPG removed.
# Original image cleaned_cleaned_untitled-429.JPG removed.
# Original image cleaned_cleaned_untitled-419.JPG removed.
# Original image cleaned_cleaned_untitled-414.JPG removed.
# Original image cleaned_cleaned_untitled-417.JPG removed.
# Original image cleaned_cleaned_untitled-416.JPG removed.
# Original image cleaned_cleaned_untitled-435.JPG removed.
# Original image cleaned_cleaned_untitled-424.JPG removed.
# Original image cleaned_cleaned_untitled-434.JPG removed.
# Original image cleaned_cleaned_untitled-43.JPG removed.
# Original image cleaned_cleaned_untitled-42.JPG removed.
# Original image cleaned_cleaned_untitled-420.JPG removed.
# Original image cleaned_cleaned_untitled-423.JPG removed.
# Original image cleaned_cleaned_untitled-418.JPG removed.
# Original image cleaned_cleaned_untitled-421.JPG removed.
# Original image cleaned_cleaned_untitled-431.JPG removed.
# Original image cleaned_cleaned_untitled-415.JPG removed.
# Original image cleaned_cleaned_untitled-427.JPG removed.
# Original image cleaned_cleaned_untitled-433.JPG removed.
# Original image cleaned_cleaned_untitled-45.JPG removed.
# Original image cleaned_cleaned_untitled-5.JPG removed.
# Original image cleaned_cleaned_untitled-69.JPG removed.
# Original image cleaned_cleaned_untitled-6.JPG removed.
# Original image cleaned_cleaned_untitled-67.JPG removed.
# Original image cleaned_cleaned_untitled-44.JPG removed.
# Original image cleaned_cleaned_untitled-439.JPG removed.
# Original image cleaned_cleaned_untitled-51.JPG removed.
# Original image cleaned_cleaned_untitled-7.JPG removed.
# Original image cleaned_cleaned_untitled-48.JPG removed.
# Original image cleaned_cleaned_untitled-65.JPG removed.
# Original image cleaned_cleaned_untitled-62.JPG removed.
# Original image cleaned_cleaned_untitled-61.JPG removed.
# Original image cleaned_cleaned_untitled-52.JPG removed.
# Original image cleaned_cleaned_untitled-47.JPG removed.
# Original image cleaned_cleaned_untitled-57.JPG removed.
# Original image cleaned_cleaned_untitled-68.JPG removed.
# Original image cleaned_cleaned_untitled-66.JPG removed.
# Original image cleaned_cleaned_untitled-55.JPG removed.
# Original image cleaned_cleaned_untitled-60.JPG removed.
# Original image cleaned_cleaned_untitled-56.JPG removed.
# Original image cleaned_cleaned_untitled-440.JPG removed.
# Original image cleaned_cleaned_untitled-54.JPG removed.
# Original image cleaned_cleaned_untitled-63.JPG removed.
# Original image cleaned_cleaned_untitled-58.JPG removed.
# Original image cleaned_cleaned_untitled-50.JPG removed.
# Original image cleaned_cleaned_untitled-46.JPG removed.
# Original image cleaned_cleaned_untitled-49.JPG removed.
# Original image cleaned_cleaned_untitled-53.JPG removed.
# Original image cleaned_cleaned_untitled-59.JPG removed.
# Original image cleaned_cleaned_untitled-64.JPG removed.
# Original image cleaned_cleaned_untitled-79.JPG removed.
# Original image cleaned_cleaned_untitled-96.JPG removed.
# Original image cleaned_cleaned_untitled-71.JPG removed.
# Original image cleaned_cleaned_untitled-80.JPG removed.
# Original image cleaned_cleaned_untitled-90.JPG removed.
# Original image cleaned_cleaned_untitled-70.JPG removed.
# Original image cleaned_cleaned_untitled-89.JPG removed.
# Original image cleaned_cleaned_untitled-9.JPG removed.
# Original image cleaned_cleaned_untitled-94.JPG removed.
# Original image cleaned_cleaned_untitled-75.JPG removed.
# Original image cleaned_cleaned_untitled-86.JPG removed.
# Original image cleaned_cleaned_untitled-81.JPG removed.
# Original image cleaned_cleaned_untitled-85.JPG removed.
# Original image cleaned_cleaned_untitled-88.JPG removed.
# Original image cleaned_cleaned_untitled-97.JPG removed.
# Original image cleaned_cleaned_untitled-78.JPG removed.
# Original image cleaned_cleaned_untitled-95.JPG removed.
# Original image cleaned_cleaned_untitled-8.JPG removed.
# Original image cleaned_cleaned_untitled-72.JPG removed.
# Original image cleaned_cleaned_untitled-93.JPG removed.
# Original image cleaned_cleaned_untitled-87.JPG removed.
# Original image cleaned_cleaned_untitled-82.JPG removed.
# Original image cleaned_cleaned_untitled-77.JPG removed.
# Original image cleaned_cleaned_untitled-83.JPG removed.
# Original image cleaned_cleaned_untitled-92.JPG removed.
# Original image cleaned_cleaned_untitled-84.JPG removed.
# Original image cleaned_cleaned_untitled-74.JPG removed.
# Original image cleaned_cleaned_untitled-91.JPG removed.
# Original image cleaned_cleaned_untitled-76.JPG removed.
# Original image cleaned_cleaned_untitled-73.JPG removed.
# Original image cleaned_cleaned_untitled-99.JPG removed.
# Original image cleaned_cleaned_untitled-98.JPG removed.
# Original image cleaned_cleaned_untitled-101.JPG removed.
# Original image cleaned_cleaned_untitled-10.JPG removed.
# Original image cleaned_cleaned_untitled-103.JPG removed.
# Original image cleaned_cleaned_untitled-104.JPG removed.
# Original image cleaned_cleaned_untitled-107.JPG removed.
# Original image cleaned_cleaned_untitled-1.JPG removed.
# Original image cleaned_cleaned_untitled-106.JPG removed.
# Original image cleaned_cleaned_untitled-102.JPG removed.
# Original image cleaned_cleaned_untitled-105.JPG removed.
# Original image cleaned_cleaned_untitled-100.JPG removed.
# Original image cleaned_cleaned_untitled-112.JPG removed.
# Original image cleaned_cleaned_untitled-115.JPG removed.
# Original image cleaned_cleaned_untitled-121.JPG removed.
# Original image cleaned_cleaned_untitled-123.JPG removed.
# Original image cleaned_cleaned_untitled-118.JPG removed.
# Original image cleaned_cleaned_untitled-114.JPG removed.
# Original image cleaned_cleaned_untitled-12.JPG removed.
# Original image cleaned_cleaned_untitled-113.JPG removed.
# Original image cleaned_cleaned_untitled-124.JPG removed.
# Original image cleaned_cleaned_untitled-119.JPG removed.
# Original image cleaned_cleaned_untitled-125.JPG removed.
# Original image cleaned_cleaned_untitled-111.JPG removed.
# Original image cleaned_cleaned_untitled-108.JPG removed.
# Original image cleaned_cleaned_untitled-110.JPG removed.
# Original image cleaned_cleaned_untitled-120.JPG removed.
# Original image cleaned_cleaned_untitled-109.JPG removed.
# Original image cleaned_cleaned_untitled-116.JPG removed.
# Original image cleaned_cleaned_untitled-122.JPG removed.
# Original image cleaned_cleaned_untitled-11.JPG removed.
# Original image cleaned_cleaned_untitled-117.JPG removed.
# Original image cleaned_cleaned_untitled-134.JPG removed.
# Original image cleaned_cleaned_untitled-13.JPG removed.
# Original image cleaned_cleaned_untitled-129.JPG removed.
# Original image cleaned_cleaned_untitled-130.JPG removed.
# Original image cleaned_cleaned_untitled-143.JPG removed.
# Original image cleaned_cleaned_untitled-127.JPG removed.
# Original image cleaned_cleaned_untitled-128.JPG removed.
# Original image cleaned_cleaned_untitled-146.JPG removed.
# Original image cleaned_cleaned_untitled-14.JPG removed.
# Original image cleaned_cleaned_untitled-139.JPG removed.
# Original image cleaned_cleaned_untitled-141.JPG removed.
# Original image cleaned_cleaned_untitled-140.JPG removed.
# Original image cleaned_cleaned_untitled-137.JPG removed.
# Original image cleaned_cleaned_untitled-133.JPG removed.
# Original image cleaned_cleaned_untitled-144.JPG removed.
# Original image cleaned_cleaned_untitled-126.JPG removed.
# Original image cleaned_cleaned_untitled-135.JPG removed.
# Original image cleaned_cleaned_untitled-145.JPG removed.
# Original image cleaned_cleaned_untitled-142.JPG removed.
# Original image cleaned_cleaned_untitled-147.JPG removed.
# Original image cleaned_cleaned_untitled-136.JPG removed.
# Original image cleaned_cleaned_untitled-132.JPG removed.
# Original image cleaned_cleaned_untitled-131.JPG removed.
# Original image cleaned_cleaned_untitled-138.JPG removed.
# Original image cleaned_cleaned_untitled-159.JPG removed.
# Original image cleaned_cleaned_untitled-155.JPG removed.
# Original image cleaned_cleaned_untitled-152.JPG removed.
# Original image cleaned_cleaned_untitled-160.JPG removed.
# Original image cleaned_cleaned_untitled-149.JPG removed.
# Original image cleaned_cleaned_untitled-158.JPG removed.
# Original image cleaned_cleaned_untitled-154.JPG removed.
# Original image cleaned_cleaned_untitled-161.JPG removed.
# Original image cleaned_cleaned_untitled-157.JPG removed.
# Original image cleaned_cleaned_untitled-148.JPG removed.
# Original image cleaned_cleaned_untitled-15.JPG removed.
# Original image cleaned_cleaned_untitled-156.JPG removed.
# Original image cleaned_cleaned_untitled-151.JPG removed.
# Original image cleaned_cleaned_untitled-162.JPG removed.
# Original image cleaned_cleaned_untitled-153.JPG removed.
# Original image cleaned_cleaned_untitled-150.JPG removed.
# Original image cleaned_cleaned_untitled-16.JPG removed.
# Original image cleaned_cleaned_untitled-171.JPG removed.
# Original image cleaned_cleaned_untitled-177.JPG removed.
# Original image cleaned_cleaned_untitled-174.JPG removed.
# Original image cleaned_cleaned_untitled-164.JPG removed.
# Original image cleaned_cleaned_untitled-169.JPG removed.
# Original image cleaned_cleaned_untitled-179.JPG removed.
# Original image cleaned_cleaned_untitled-17.JPG removed.
# Original image cleaned_cleaned_untitled-173.JPG removed.
# Original image cleaned_cleaned_untitled-180.JPG removed.
# Original image cleaned_cleaned_untitled-172.JPG removed.
# Original image cleaned_cleaned_untitled-175.JPG removed.
# Original image cleaned_cleaned_untitled-163.JPG removed.
# Original image cleaned_cleaned_untitled-178.JPG removed.
# Original image cleaned_cleaned_untitled-181.JPG removed.
# Original image cleaned_cleaned_untitled-168.JPG removed.
# Original image cleaned_cleaned_untitled-165.JPG removed.
# Original image cleaned_cleaned_untitled-166.JPG removed.
# Original image cleaned_cleaned_untitled-18.JPG removed.
# Original image cleaned_cleaned_untitled-167.JPG removed.
# Original image cleaned_cleaned_untitled-170.JPG removed.
# Original image cleaned_cleaned_untitled-176.JPG removed.
# Original image cleaned_cleaned_untitled-186.JPG removed.
# Original image cleaned_cleaned_untitled-199.JPG removed.
# Original image cleaned_cleaned_untitled-20.JPG removed.
# Original image cleaned_cleaned_untitled-201.JPG removed.
# Original image cleaned_cleaned_untitled-200.JPG removed.
# Original image cleaned_cleaned_untitled-197.JPG removed.
# Original image cleaned_cleaned_untitled-187.JPG removed.
# Original image cleaned_cleaned_untitled-194.JPG removed.
# Original image cleaned_cleaned_untitled-188.JPG removed.
# Original image cleaned_cleaned_untitled-196.JPG removed.
# Original image cleaned_cleaned_untitled-195.JPG removed.
# Original image cleaned_cleaned_untitled-198.JPG removed.
# Original image cleaned_cleaned_untitled-183.JPG removed.
# Original image cleaned_cleaned_untitled-189.JPG removed.
# Original image cleaned_cleaned_untitled-191.JPG removed.
# Original image cleaned_cleaned_untitled-19.JPG removed.
# Original image cleaned_cleaned_untitled-185.JPG removed.
# Original image cleaned_cleaned_untitled-202.JPG removed.
# Original image cleaned_cleaned_untitled-190.JPG removed.
# Original image cleaned_cleaned_untitled-182.JPG removed.
# Original image cleaned_cleaned_untitled-184.JPG removed.
# Original image cleaned_cleaned_untitled-192.JPG removed.
# Original image cleaned_cleaned_untitled-2.JPG removed.
# Original image cleaned_cleaned_untitled-193.JPG removed.
# Original image cleaned_cleaned_untitled-226.JPG removed.
# Original image cleaned_cleaned_untitled-210.JPG removed.
# Original image cleaned_cleaned_untitled-214.JPG removed.
# Original image cleaned_cleaned_untitled-225.JPG removed.
# Original image cleaned_cleaned_untitled-217.JPG removed.
# Original image cleaned_cleaned_untitled-229.JPG removed.
# Original image cleaned_cleaned_untitled-213.JPG removed.
# Original image cleaned_cleaned_untitled-216.JPG removed.
# Original image cleaned_cleaned_untitled-209.JPG removed.
# Original image cleaned_cleaned_untitled-220.JPG removed.
# Original image cleaned_cleaned_untitled-215.JPG removed.
# Original image cleaned_cleaned_untitled-212.JPG removed.
# Original image cleaned_cleaned_untitled-204.JPG removed.
# Original image cleaned_cleaned_untitled-223.JPG removed.
# Original image cleaned_cleaned_untitled-206.JPG removed.
# Original image cleaned_cleaned_untitled-208.JPG removed.
# Original image cleaned_cleaned_untitled-207.JPG removed.
# Original image cleaned_cleaned_untitled-224.JPG removed.
# Original image cleaned_cleaned_untitled-227.JPG removed.
# Original image cleaned_cleaned_untitled-228.JPG removed.
# Original image cleaned_cleaned_untitled-221.JPG removed.
# Original image cleaned_cleaned_untitled-22.JPG removed.
# Original image cleaned_cleaned_untitled-205.JPG removed.
# Original image cleaned_cleaned_untitled-222.JPG removed.
# Original image cleaned_cleaned_untitled-21.JPG removed.
# Original image cleaned_cleaned_untitled-203.JPG removed.
# Original image cleaned_cleaned_untitled-218.JPG removed.
# Original image cleaned_cleaned_untitled-211.JPG removed.
# Original image cleaned_cleaned_untitled-219.JPG removed.
# Original image cleaned_cleaned_untitled-235.JPG removed.
# Original image cleaned_cleaned_untitled-245.JPG removed.
# Original image cleaned_cleaned_untitled-238.JPG removed.
# Original image cleaned_cleaned_untitled-230.JPG removed.
# Original image cleaned_cleaned_untitled-244.JPG removed.
# Original image cleaned_cleaned_untitled-234.JPG removed.
# Original image cleaned_cleaned_untitled-23.JPG removed.
# Original image cleaned_cleaned_untitled-233.JPG removed.
# Original image cleaned_cleaned_untitled-242.JPG removed.
# Original image cleaned_cleaned_untitled-246.JPG removed.
# Original image cleaned_cleaned_untitled-243.JPG removed.
# Original image cleaned_cleaned_untitled-236.JPG removed.
# Original image cleaned_cleaned_untitled-231.JPG removed.
# Original image cleaned_cleaned_untitled-25.JPG removed.
# Original image cleaned_cleaned_untitled-24.JPG removed.
# Original image cleaned_cleaned_untitled-239.JPG removed.
# Original image cleaned_cleaned_untitled-248.JPG removed.
# Original image cleaned_cleaned_untitled-240.JPG removed.
# Original image cleaned_cleaned_untitled-237.JPG removed.
# Original image cleaned_cleaned_untitled-232.JPG removed.
# Original image cleaned_cleaned_untitled-249.JPG removed.
# Original image cleaned_cleaned_untitled-241.JPG removed.
# Original image cleaned_cleaned_untitled-247.JPG removed.
# Original image cleaned_cleaned_untitled-258.JPG removed.
# Original image cleaned_cleaned_untitled-252.JPG removed.
# Original image cleaned_cleaned_untitled-273.JPG removed.
# Original image cleaned_cleaned_untitled-262.JPG removed.
# Original image cleaned_cleaned_untitled-260.JPG removed.
# Original image cleaned_cleaned_untitled-269.JPG removed.
# Original image cleaned_cleaned_untitled-266.JPG removed.
# Original image cleaned_cleaned_untitled-259.JPG removed.
# Original image cleaned_cleaned_untitled-250.JPG removed.
# Original image cleaned_cleaned_untitled-255.JPG removed.
# Original image cleaned_cleaned_untitled-274.JPG removed.
# Original image cleaned_cleaned_untitled-26.JPG removed.
# Original image cleaned_cleaned_untitled-256.JPG removed.
# Original image cleaned_cleaned_untitled-267.JPG removed.
# Original image cleaned_cleaned_untitled-263.JPG removed.
# Original image cleaned_cleaned_untitled-27.JPG removed.
# Original image cleaned_cleaned_untitled-268.JPG removed.
# Original image cleaned_cleaned_untitled-254.JPG removed.
# Original image cleaned_cleaned_untitled-272.JPG removed.
# Original image cleaned_cleaned_untitled-270.JPG removed.
# Original image cleaned_cleaned_untitled-264.JPG removed.
# Original image cleaned_cleaned_untitled-251.JPG removed.
# Original image cleaned_cleaned_untitled-265.JPG removed.
# Original image cleaned_cleaned_untitled-271.JPG removed.
# Original image cleaned_cleaned_untitled-253.JPG removed.
# Original image cleaned_cleaned_untitled-261.JPG removed.
# Original image cleaned_cleaned_untitled-275.JPG removed.
# Original image cleaned_cleaned_untitled-292.JPG removed.
# Original image cleaned_cleaned_untitled-291.JPG removed.
# Original image cleaned_cleaned_untitled-276.JPG removed.
# Original image cleaned_cleaned_untitled-281.JPG removed.
# Original image cleaned_cleaned_untitled-277.JPG removed.
# Original image cleaned_cleaned_untitled-294.JPG removed.
# Original image cleaned_cleaned_untitled-278.JPG removed.
# Original image cleaned_cleaned_untitled-279.JPG removed.
# Original image cleaned_cleaned_untitled-290.JPG removed.
# Original image cleaned_cleaned_untitled-295.JPG removed.
# Original image cleaned_cleaned_untitled-28.JPG removed.
# Original image cleaned_cleaned_untitled-293.JPG removed.
# Original image cleaned_cleaned_untitled-284.JPG removed.
# Original image cleaned_cleaned_untitled-29.JPG removed.
# Original image cleaned_cleaned_untitled-285.JPG removed.
# Original image cleaned_cleaned_untitled-296.JPG removed.
# Original image cleaned_cleaned_untitled-282.JPG removed.
# Original image cleaned_cleaned_untitled-283.JPG removed.
# Original image cleaned_cleaned_untitled-286.JPG removed.
# Original image cleaned_cleaned_untitled-289.JPG removed.
# Original image cleaned_cleaned_untitled-287.JPG removed.
# Original image cleaned_cleaned_untitled-288.JPG removed.
# Original image cleaned_cleaned_untitled-280.JPG removed.
# Original image cleaned_cleaned_untitled-304.JPG removed.
# Original image cleaned_cleaned_untitled-3.JPG removed.
# Original image cleaned_cleaned_untitled-300.JPG removed.
# Original image cleaned_cleaned_untitled-302.JPG removed.
# Original image cleaned_cleaned_untitled-305.JPG removed.
# Original image cleaned_cleaned_untitled-301.JPG removed.
# Original image cleaned_cleaned_untitled-297.JPG removed.
# Original image cleaned_cleaned_untitled-30.JPG removed.
# Original image cleaned_cleaned_untitled-303.JPG removed.
# Original image cleaned_cleaned_untitled-313.JPG removed.
# Original image cleaned_cleaned_untitled-298.JPG removed.
# Original image cleaned_cleaned_untitled-306.JPG removed.
# Original image cleaned_cleaned_untitled-310.JPG removed.
# Original image cleaned_cleaned_untitled-299.JPG removed.
# Original image cleaned_cleaned_untitled-311.JPG removed.
# Original image cleaned_cleaned_untitled-307.JPG removed.
# Original image cleaned_cleaned_untitled-31.JPG removed.
# Original image cleaned_cleaned_untitled-308.JPG removed.
# Original image cleaned_cleaned_untitled-312.JPG removed.
# Original image cleaned_cleaned_untitled-309.JPG removed.
# Original image cleaned_cleaned_untitled-323.JPG removed.
# Original image cleaned_cleaned_untitled-332.JPG removed.
# Original image cleaned_cleaned_untitled-33.JPG removed.
# Original image cleaned_cleaned_untitled-317.JPG removed.
# Original image cleaned_cleaned_untitled-319.JPG removed.
# Original image cleaned_cleaned_untitled-318.JPG removed.
# Original image cleaned_cleaned_untitled-325.JPG removed.
# Original image cleaned_cleaned_untitled-314.JPG removed.
# Original image cleaned_cleaned_untitled-328.JPG removed.
# Original image cleaned_cleaned_untitled-333.JPG removed.
# Original image cleaned_cleaned_untitled-330.JPG removed.
# Original image cleaned_cleaned_untitled-32.JPG removed.
# Original image cleaned_cleaned_untitled-320.JPG removed.
# Original image cleaned_cleaned_untitled-321.JPG removed.
# Original image cleaned_cleaned_untitled-327.JPG removed.
# Original image cleaned_cleaned_untitled-326.JPG removed.
# Original image cleaned_cleaned_untitled-334.JPG removed.
# Original image cleaned_cleaned_untitled-329.JPG removed.
# Original image cleaned_cleaned_untitled-322.JPG removed.
# Original image cleaned_cleaned_untitled-316.JPG removed.
# Original image cleaned_cleaned_untitled-324.JPG removed.
# Original image cleaned_cleaned_untitled-331.JPG removed.
# Original image cleaned_cleaned_untitled-315.JPG removed.
# Original image cleaned_cleaned_untitled-348.JPG removed.
# Original image cleaned_cleaned_untitled-344.JPG removed.
# Original image cleaned_cleaned_untitled-350.JPG removed.
# Original image cleaned_cleaned_untitled-346.JPG removed.
# Original image cleaned_cleaned_untitled-340.JPG removed.
# Original image cleaned_cleaned_untitled-336.JPG removed.
# Original image cleaned_cleaned_untitled-349.JPG removed.
# Original image cleaned_cleaned_untitled-351.JPG removed.
# Original image cleaned_cleaned_untitled-338.JPG removed.
# Original image cleaned_cleaned_untitled-342.JPG removed.
# Original image cleaned_cleaned_untitled-35.JPG removed.
# Original image cleaned_cleaned_untitled-347.JPG removed.
# Original image cleaned_cleaned_untitled-339.JPG removed.
# Original image cleaned_cleaned_untitled-352.JPG removed.
# Original image cleaned_cleaned_untitled-343.JPG removed.
# Original image cleaned_cleaned_untitled-341.JPG removed.
# Original image cleaned_cleaned_untitled-337.JPG removed.
# Original image cleaned_cleaned_untitled-34.JPG removed.
# Original image cleaned_cleaned_untitled-345.JPG removed.
# Original image cleaned_cleaned_untitled-335.JPG removed.
# Original image cleaned_cleaned_untitled-361.JPG removed.
# Original image cleaned_cleaned_untitled-360.JPG removed.
# Original image cleaned_cleaned_untitled-357.JPG removed.
# Original image cleaned_cleaned_untitled-355.JPG removed.
# Original image cleaned_cleaned_untitled-367.JPG removed.
# Original image cleaned_cleaned_untitled-362.JPG removed.
# Original image cleaned_cleaned_untitled-356.JPG removed.
# Original image cleaned_cleaned_untitled-365.JPG removed.
# Original image cleaned_cleaned_untitled-358.JPG removed.
# Original image cleaned_cleaned_untitled-363.JPG removed.
# Original image cleaned_cleaned_untitled-36.JPG removed.
# Original image cleaned_cleaned_untitled-359.JPG removed.
# Original image cleaned_cleaned_untitled-364.JPG removed.
# Original image cleaned_cleaned_untitled-354.JPG removed.
# Original image cleaned_cleaned_untitled-369.JPG removed.
# Original image cleaned_cleaned_untitled-353.JPG removed.
# Original image cleaned_cleaned_untitled-366.JPG removed.
# Original image cleaned_cleaned_untitled-368.JPG removed.
# Original image cleaned_cleaned_untitled-376.JPG removed.
# Original image cleaned_cleaned_untitled-380.JPG removed.
# Original image cleaned_cleaned_untitled-384.JPG removed.
# Original image cleaned_cleaned_untitled-382.JPG removed.
# Original image cleaned_cleaned_untitled-378.JPG removed.
# Original image cleaned_cleaned_untitled-373.JPG removed.
# Original image cleaned_cleaned_untitled-37.JPG removed.
# Original image cleaned_cleaned_untitled-377.JPG removed.
# Original image cleaned_cleaned_untitled-39.JPG removed.
# Original image cleaned_cleaned_untitled-383.JPG removed.
# Original image cleaned_cleaned_untitled-38.JPG removed.
# Original image cleaned_cleaned_untitled-371.JPG removed.
# Original image cleaned_cleaned_untitled-381.JPG removed.
# Original image cleaned_cleaned_untitled-372.JPG removed.
# Original image cleaned_cleaned_untitled-375.JPG removed.
# Original image cleaned_cleaned_untitled-374.JPG removed.
# Original image cleaned_cleaned_untitled-370.JPG removed.
# Original image cleaned_cleaned_untitled-379.JPG removed.
# Original image cleaned_cleaned_untitled-55.JPG removed.
# Original image cleaned_cleaned_untitled-5.JPG removed.
# Original image cleaned_cleaned_untitled-52.JPG removed.
# Original image cleaned_cleaned_untitled-40.JPG removed.
# Original image cleaned_cleaned_untitled-41.JPG removed.
# Original image cleaned_cleaned_untitled-45.JPG removed.
# Original image cleaned_cleaned_untitled-44.JPG removed.
# Original image cleaned_cleaned_untitled-57.JPG removed.
# Original image cleaned_cleaned_untitled-42.JPG removed.
# Original image cleaned_cleaned_untitled-51.JPG removed.
# Original image cleaned_cleaned_untitled-49.JPG removed.
# Original image cleaned_cleaned_untitled-47.JPG removed.
# Original image cleaned_cleaned_untitled-56.JPG removed.
# Original image cleaned_cleaned_untitled-53.JPG removed.
# Original image cleaned_cleaned_untitled-59.JPG removed.
# Original image cleaned_cleaned_untitled-46.JPG removed.
# Original image cleaned_cleaned_untitled-48.JPG removed.
# Original image cleaned_cleaned_untitled-54.JPG removed.
# Original image cleaned_cleaned_untitled-58.JPG removed.
# Original image cleaned_cleaned_untitled-50.JPG removed.
# Original image cleaned_cleaned_untitled-43.JPG removed.
# Original image cleaned_cleaned_untitled-4.JPG removed.
# Original image cleaned_cleaned_untitled-63.JPG removed.
# Original image cleaned_cleaned_untitled-79.JPG removed.
# Original image cleaned_cleaned_untitled-75.JPG removed.
# Original image cleaned_cleaned_untitled-7.JPG removed.
# Original image cleaned_cleaned_untitled-78.JPG removed.
# Original image cleaned_cleaned_untitled-66.JPG removed.
# Original image cleaned_cleaned_untitled-60.JPG removed.
# Original image cleaned_cleaned_untitled-65.JPG removed.
# Original image cleaned_cleaned_untitled-69.JPG removed.
# Original image cleaned_cleaned_untitled-67.JPG removed.
# Original image cleaned_cleaned_untitled-61.JPG removed.
# Original image cleaned_cleaned_untitled-72.JPG removed.
# Original image cleaned_cleaned_untitled-77.JPG removed.
# Original image cleaned_cleaned_untitled-62.JPG removed.
# Original image cleaned_cleaned_untitled-74.JPG removed.
# Original image cleaned_cleaned_untitled-70.JPG removed.
# Original image cleaned_cleaned_untitled-68.JPG removed.
# Original image cleaned_cleaned_untitled-73.JPG removed.
# Original image cleaned_cleaned_untitled-64.JPG removed.
# Original image cleaned_cleaned_untitled-76.JPG removed.
# Original image cleaned_cleaned_untitled-71.JPG removed.
# Original image cleaned_cleaned_untitled-6.JPG removed.
# Original image cleaned_cleaned_untitled-81.JPG removed.
# Original image cleaned_cleaned_untitled-80.JPG removed.
# Original image cleaned_cleaned_untitled-85.JPG removed.
# Original image cleaned_cleaned_untitled-91.JPG removed.
# Original image cleaned_cleaned_untitled-9.JPG removed.
# Original image cleaned_cleaned_untitled-96.JPG removed.
# Original image cleaned_cleaned_untitled-98.JPG removed.
# Original image cleaned_cleaned_untitled-97.JPG removed.
# Original image cleaned_cleaned_untitled-95.JPG removed.
# Original image cleaned_cleaned_untitled-93.JPG removed.
# Original image cleaned_cleaned_untitled-99.JPG removed.
# Original image cleaned_cleaned_untitled-86.JPG removed.
# Original image cleaned_cleaned_untitled-82.JPG removed.
# Original image cleaned_cleaned_untitled-83.JPG removed.
# Original image cleaned_cleaned_untitled-89.JPG removed.
# Original image cleaned_cleaned_untitled-8.JPG removed.
# Original image cleaned_cleaned_untitled-90.JPG removed.
# Original image cleaned_cleaned_untitled-94.JPG removed.
# Original image cleaned_cleaned_untitled-92.JPG removed.
# Original image cleaned_cleaned_untitled-88.JPG removed.
# Original image cleaned_cleaned_untitled-87.JPG removed.
# Original image cleaned_cleaned_untitled-84.JPG removed.
# Original image cleaned_cleaned_IMG_3792.JPG removed.
# Original image cleaned_cleaned_IMG_4094.JPG removed.
# Original image cleaned_cleaned_IMG_3786.JPG removed.
# Original image cleaned_cleaned_IMG_3784.JPG removed.
# Original image cleaned_cleaned_IMG_4091.JPG removed.
# Original image cleaned_cleaned_IMG_3794.JPG removed.
# Original image cleaned_cleaned_IMG_3793.JPG removed.
# Original image cleaned_cleaned_IMG_3785.JPG removed.
# Original image cleaned_cleaned_IMG_3805.JPG removed.
# Original image cleaned_cleaned_IMG_3796.JPG removed.
# Original image cleaned_cleaned_IMG_4265.JPG removed.
# Original image cleaned_cleaned_IMG_3801.JPG removed.
# Original image cleaned_cleaned_IMG_3791.JPG removed.
# Original image cleaned_cleaned_IMG_4257-4.JPG removed.
# Original image cleaned_cleaned_IMG_3789.JPG removed.
# Original image cleaned_cleaned_IMG_3787.JPG removed.
# Original image cleaned_cleaned_IMG_3788.JPG removed.
# Original image cleaned_cleaned_IMG_4265-7.JPG removed.
# Original image cleaned_cleaned_IMG_3795.JPG removed.
# Original image cleaned_cleaned_IMG_4095.JPG removed.
# Original image cleaned_cleaned_IMG_4322.JPG removed.
# Original image cleaned_cleaned_IMG_3808.JPG removed.
# Original image cleaned_cleaned_IMG_3810.JPG removed.
# Original image cleaned_cleaned_IMG_4290.JPG removed.
# ...
# Original image cleaned_cleaned_IMG_4100.JPG removed.
# Original image cleaned_cleaned_IMG_5427.JPG removed.
# Original image cleaned_cleaned_IMG_4102.JPG removed.
# Original image cleaned_cleaned_IMG_4101.JPG removed.
# Original image cleaned_cleaned_IMG_5429.JPG removed.
# Original image cleaned_cleaned_IMG_4098.JPG removed.
# Original image cleaned_cleaned_IMG_4105.JPG removed.
# Original image cleaned_cleaned_IMG_5429-18.JPG removed.
# Original image cleaned_cleaned_IMG_4104.JPG removed.
# Original image cleaned_cleaned_IMG_4109.JPG removed.
# Original image cleaned_cleaned_IMG_5435-24.JPG removed.
# Original image cleaned_cleaned_IMG_4107.JPG removed.
# Original image cleaned_cleaned_IMG_5430.JPG removed.
# Original image cleaned_cleaned_IMG_4097.JPG removed.
# Original image cleaned_cleaned_IMG_4096.JPG removed.
# Original image cleaned_cleaned_IMG_5430-19.JPG removed.
# Original image cleaned_cleaned_IMG_4113.JPG removed.
# Original image cleaned_cleaned_IMG_5436-25.JPG removed.
# Original image cleaned_cleaned_IMG_4108.JPG removed.
# Original image cleaned_cleaned_IMG_4106.JPG removed.
# Original image cleaned_cleaned_IMG_5435.JPG removed.
# Original image cleaned_cleaned_IMG_4111.JPG removed.
# Original image cleaned_cleaned_IMG_4112.JPG removed.
# Original image cleaned_cleaned_IMG_4123.JPG removed.
# Original image cleaned_cleaned_IMG_4126.JPG removed.
# Original image cleaned_cleaned_IMG_4125.JPG removed.
# Original image cleaned_cleaned_IMG_4110.JPG removed.
# Original image cleaned_cleaned_IMG_4114.JPG removed.
# Original image cleaned_cleaned_IMG_4115.JPG removed.
# Original image cleaned_cleaned_IMG_4118.JPG removed.
# Original image cleaned_cleaned_IMG_4120.JPG removed.
# Original image cleaned_cleaned_IMG_4117.JPG removed.
# Original image cleaned_cleaned_IMG_4124.JPG removed.
# Original image cleaned_cleaned_IMG_4122.JPG removed.
# Original image cleaned_cleaned_IMG_4121.JPG removed.
# Original image cleaned_cleaned_IMG_4116.JPG removed.
# Original image cleaned_cleaned_IMG_4134.JPG removed.
# Original image cleaned_cleaned_IMG_4131.JPG removed.
# Original image cleaned_cleaned_IMG_4130.JPG removed.
# Original image cleaned_cleaned_IMG_4127.JPG removed.
# Original image cleaned_cleaned_IMG_4133.JPG removed.
# Original image cleaned_cleaned_IMG_4132.JPG removed.
# Original image cleaned_cleaned_IMG_4128.JPG removed.
# Original image cleaned_cleaned_IMG_4129.JPG removed.
# Original image cleaned_cleaned_IMG_4136.JPG removed.
# Original image cleaned_cleaned_IMG_4135.JPG removed.
# Original image cleaned_cleaned_IMG_4259.JPG removed.
# Original image cleaned_cleaned_IMG_4263.JPG removed.
# Original image cleaned_cleaned_IMG_4261.JPG removed.
# Original image cleaned_cleaned_IMG_4260.JPG removed.
# Original image cleaned_cleaned_IMG_4258-5.JPG removed.
# Original image cleaned_cleaned_IMG_4254-1.JPG removed.
# Original image cleaned_cleaned_IMG_4255-2.JPG removed.
# Original image cleaned_cleaned_IMG_4269.JPG removed.
# Original image cleaned_cleaned_IMG_4264.JPG removed.
# Original image cleaned_cleaned_IMG_4262.JPG removed.
# Original image cleaned_cleaned_IMG_4256-3.JPG removed.
# Original image cleaned_cleaned_IMG_4263-6.JPG removed.
# Original image cleaned_cleaned_IMG_4274-9.JPG removed.
# Original image cleaned_cleaned_IMG_4271.JPG removed.
# Original image cleaned_cleaned_IMG_4266.JPG removed.
# Original image cleaned_cleaned_IMG_4268.JPG removed.
# Original image cleaned_cleaned_IMG_4272-8.JPG removed.
# Original image cleaned_cleaned_IMG_4274.JPG removed.
# Original image cleaned_cleaned_IMG_4277-12.JPG removed.
# Original image cleaned_cleaned_IMG_4276.JPG removed.
# Original image cleaned_cleaned_IMG_4273.JPG removed.
# Original image cleaned_cleaned_IMG_4267.JPG removed.
# Original image cleaned_cleaned_IMG_4272.JPG removed.
# Original image cleaned_cleaned_IMG_4279-14.JPG removed.
# Original image cleaned_cleaned_IMG_4278-13.JPG removed.
# Original image cleaned_cleaned_IMG_4277.JPG removed.
# Original image cleaned_cleaned_IMG_4276-11.JPG removed.
# Original image cleaned_cleaned_IMG_4275.JPG removed.
# Original image cleaned_cleaned_IMG_4275-10.JPG removed.
# Original image cleaned_cleaned_IMG_4281-16.JPG removed.
# Original image cleaned_cleaned_IMG_4283-18.JPG removed.
# Original image cleaned_cleaned_IMG_4284-19.JPG removed.
# Original image cleaned_cleaned_IMG_4279.JPG removed.
# Original image cleaned_cleaned_IMG_4283.JPG removed.
# Original image cleaned_cleaned_IMG_4278.JPG removed.
# Original image cleaned_cleaned_IMG_4282.JPG removed.
# Original image cleaned_cleaned_IMG_4282-17.JPG removed.
# Original image cleaned_cleaned_IMG_4280.JPG removed.
# Original image cleaned_cleaned_IMG_4280-15.JPG removed.
# Original image cleaned_cleaned_IMG_4281.JPG removed.
# Original image cleaned_cleaned_IMG_4286.JPG removed.
# Original image cleaned_cleaned_IMG_4286-21.JPG removed.
# Original image cleaned_cleaned_IMG_4285.JPG removed.
# Original image cleaned_cleaned_IMG_4288.JPG removed.
# Original image cleaned_cleaned_IMG_4287.JPG removed.
# Original image cleaned_cleaned_IMG_4284.JPG removed.
# Original image cleaned_cleaned_IMG_4288-23.JPG removed.
# Original image cleaned_cleaned_IMG_4285-20.JPG removed.
# Original image cleaned_cleaned_IMG_4292.JPG removed.
# Original image cleaned_cleaned_IMG_4294.JPG removed.
# Original image cleaned_cleaned_IMG_4296.JPG removed.
# Original image cleaned_cleaned_IMG_4287-22.JPG removed.
# Original image cleaned_cleaned_IMG_4291.JPG removed.
# Original image cleaned_cleaned_IMG_4303-29.JPG removed.
# Original image cleaned_cleaned_IMG_4301-27.JPG removed.
# Original image cleaned_cleaned_IMG_4301.JPG removed.
# Original image cleaned_cleaned_IMG_4300.JPG removed.
# Original image cleaned_cleaned_IMG_4301-27-2.JPG removed.
# Original image cleaned_cleaned_IMG_4297.JPG removed.
# Original image cleaned_cleaned_IMG_4299-25.JPG removed.
# Original image cleaned_cleaned_IMG_4298.JPG removed.
# Original image cleaned_cleaned_IMG_4293.JPG removed.
# Original image cleaned_cleaned_IMG_4300-26.JPG removed.
# Original image cleaned_cleaned_IMG_4295.JPG removed.
# Original image cleaned_cleaned_IMG_4299.JPG removed.
# Original image cleaned_cleaned_IMG_4310.JPG removed.
# Original image cleaned_cleaned_IMG_4307.JPG removed.
# Original image cleaned_cleaned_IMG_4310-34.JPG removed.
# Original image cleaned_cleaned_IMG_4305-31.JPG removed.
# Original image cleaned_cleaned_IMG_4305.JPG removed.
# Original image cleaned_cleaned_IMG_4306.JPG removed.
# Original image cleaned_cleaned_IMG_4309-33.JPG removed.
# Original image cleaned_cleaned_IMG_4308-32.JPG removed.
# Original image cleaned_cleaned_IMG_4303.JPG removed.
# Original image cleaned_cleaned_IMG_4304.JPG removed.
# Original image cleaned_cleaned_IMG_4302-28.JPG removed.
# Original image cleaned_cleaned_IMG_4302.JPG removed.
# Original image cleaned_cleaned_IMG_4304-30.JPG removed.
# Original image cleaned_cleaned_IMG_4316.JPG removed.
# Original image cleaned_cleaned_IMG_4320-35.JPG removed.
# Original image cleaned_cleaned_IMG_4318.JPG removed.
# Original image cleaned_cleaned_IMG_4312.JPG removed.
# Original image cleaned_cleaned_IMG_4313.JPG removed.
# Original image cleaned_cleaned_IMG_4319.JPG removed.
# Original image cleaned_cleaned_IMG_4320.JPG removed.
# Original image cleaned_cleaned_IMG_4317.JPG removed.
# Original image cleaned_cleaned_IMG_4315.JPG removed.
# Original image cleaned_cleaned_IMG_4314.JPG removed.
# Original image cleaned_cleaned_IMG_4309.JPG removed.
# Original image cleaned_cleaned_IMG_4308.JPG removed.
# Original image cleaned_cleaned_IMG_4333.JPG removed.
# Original image cleaned_cleaned_IMG_4334.JPG removed.
# Original image cleaned_cleaned_IMG_4332.JPG removed.
# Original image cleaned_cleaned_IMG_4327.JPG removed.
# Original image cleaned_cleaned_IMG_4326.JPG removed.
# Original image cleaned_cleaned_IMG_4324.JPG removed.
# Original image cleaned_cleaned_IMG_4321.JPG removed.
# Original image cleaned_cleaned_IMG_4330.JPG removed.
# Original image cleaned_cleaned_IMG_4323-36.JPG removed.
# Original image cleaned_cleaned_IMG_4329.JPG removed.
# Original image cleaned_cleaned_IMG_4325.JPG removed.
# Original image cleaned_cleaned_IMG_4342.JPG removed.
# Original image cleaned_cleaned_IMG_4335.JPG removed.
# Original image cleaned_cleaned_IMG_4339.JPG removed.
# Original image cleaned_cleaned_IMG_4335-37.JPG removed.
# Original image cleaned_cleaned_IMG_4336-38.JPG removed.
# Original image cleaned_cleaned_IMG_4340-39.JPG removed.
# Original image cleaned_cleaned_IMG_4351.JPG removed.
# Original image cleaned_cleaned_IMG_4350.JPG removed.
# Original image cleaned_cleaned_IMG_4573.JPG removed.
# Original image cleaned_cleaned_IMG_4355.JPG removed.
# Original image cleaned_cleaned_IMG_4347.JPG removed.
# Original image cleaned_cleaned_IMG_4354.JPG removed.
# Original image cleaned_cleaned_IMG_4345.JPG removed.
# Original image cleaned_cleaned_IMG_4352.JPG removed.
# Original image cleaned_cleaned_IMG_4338.JPG removed.
# Original image cleaned_cleaned_IMG_4337.JPG removed.
# Original image cleaned_cleaned_IMG_4336.JPG removed.
# Original image cleaned_cleaned_IMG_4346.JPG removed.
# Original image cleaned_cleaned_IMG_4348.JPG removed.
# Original image cleaned_cleaned_IMG_4596.JPG removed.
# Original image cleaned_cleaned_IMG_4598.JPG removed.
# Original image cleaned_cleaned_IMG_4594.JPG removed.
# Original image cleaned_cleaned_IMG_4581.JPG removed.
# Original image cleaned_cleaned_IMG_4588.JPG removed.
# Original image cleaned_cleaned_IMG_4597.JPG removed.
# Original image cleaned_cleaned_IMG_4583.JPG removed.
# Original image cleaned_cleaned_IMG_4589.JPG removed.
# Original image cleaned_cleaned_IMG_4584.JPG removed.
# Original image cleaned_cleaned_IMG_4580.JPG removed.
# Original image cleaned_cleaned_IMG_4582.JPG removed.
# Original image cleaned_cleaned_IMG_4586.JPG removed.
# Original image cleaned_cleaned_IMG_4579.JPG removed.
# Original image cleaned_cleaned_IMG_4585.JPG removed.
# Original image cleaned_cleaned_IMG_4578.JPG removed.
# Original image cleaned_cleaned_IMG_4577.JPG removed.
# Original image cleaned_cleaned_IMG_4611.JPG removed.
# Original image cleaned_cleaned_IMG_4610.JPG removed.
# Original image cleaned_cleaned_IMG_4607.JPG removed.
# Original image cleaned_cleaned_IMG_4608.JPG removed.
# Original image cleaned_cleaned_IMG_4606.JPG removed.
# Original image cleaned_cleaned_IMG_4602.JPG removed.
# Original image cleaned_cleaned_IMG_4600.JPG removed.
# Original image cleaned_cleaned_IMG_4605.JPG removed.
# Original image cleaned_cleaned_IMG_4603.JPG removed.
# Original image cleaned_cleaned_IMG_4601.JPG removed.
# Original image cleaned_cleaned_IMG_4592.JPG removed.
# Original image cleaned_cleaned_IMG_4593.JPG removed.
# Original image cleaned_cleaned_IMG_4590.JPG removed.
# Original image cleaned_cleaned_IMG_4591.JPG removed.
# Original image cleaned_cleaned_IMG_5412-1.JPG removed.
# Original image cleaned_cleaned_IMG_4616.JPG removed.
# Original image cleaned_cleaned_IMG_4618.JPG removed.
# Original image cleaned_cleaned_IMG_4621.JPG removed.
# Original image cleaned_cleaned_IMG_4615.JPG removed.
# Original image cleaned_cleaned_IMG_4612.JPG removed.
# Original image cleaned_cleaned_IMG_4614.JPG removed.
# Original image cleaned_cleaned_IMG_4613.JPG removed.
# Original image cleaned_cleaned_IMG_4617.JPG removed.
# Original image cleaned_cleaned_IMG_4619.JPG removed.
# Original image cleaned_cleaned_IMG_4620.JPG removed.
# Original image cleaned_cleaned_IMG_5422-11.JPG removed.
# Original image cleaned_cleaned_IMG_5426-15.JPG removed.
# Original image cleaned_cleaned_IMG_5423.JPG removed.
# Original image cleaned_cleaned_IMG_5422.JPG removed.
# Original image cleaned_cleaned_IMG_5418-7.JPG removed.
# Original image cleaned_cleaned_IMG_5415-4.JPG removed.
# Original image cleaned_cleaned_IMG_5419-8.JPG removed.
# Original image cleaned_cleaned_IMG_5413-2.JPG removed.
# Original image cleaned_cleaned_IMG_5414.JPG removed.
# Original image cleaned_cleaned_IMG_5415.JPG removed.
# Original image cleaned_cleaned_IMG_5416-5.JPG removed.
# Original image cleaned_cleaned_IMG_5412.JPG removed.
# Original image cleaned_cleaned_IMG_5414-3.JPG removed.
# Original image cleaned_cleaned_IMG_5413.JPG removed.
# Original image cleaned_cleaned_IMG_5431-20.JPG removed.
# Original image cleaned_cleaned_IMG_5432.JPG removed.
# Original image cleaned_cleaned_IMG_5432-21.JPG removed.
# Original image cleaned_cleaned_IMG_5426.JPG removed.
# Original image cleaned_cleaned_IMG_5433.JPG removed.
# Original image cleaned_cleaned_IMG_5421.JPG removed.
# Original image cleaned_cleaned_IMG_5428.JPG removed.
# Original image cleaned_cleaned_IMG_5434.JPG removed.
# Original image cleaned_cleaned_IMG_5433-22.JPG removed.
# Original image cleaned_cleaned_IMG_5423-12.JPG removed.
# Original image cleaned_cleaned_IMG_5421-10.JPG removed.
# Original image cleaned_cleaned_IMG_5418.JPG removed.
# Original image cleaned_cleaned_IMG_5419.JPG removed.
# Original image cleaned_cleaned_IMG_5441-30.JPG removed.
# Original image cleaned_cleaned_IMG_5439-28.JPG removed.
# Original image cleaned_cleaned_IMG_5444.JPG removed.
# Original image cleaned_cleaned_IMG_5445-34.JPG removed.
# Original image cleaned_cleaned_IMG_5437-26.JPG removed.
# Original image cleaned_cleaned_IMG_5439.JPG removed.
# Original image cleaned_cleaned_IMG_5442-31.JPG removed.
# Original image cleaned_cleaned_IMG_5442.JPG removed.
# Original image cleaned_cleaned_IMG_5441.JPG removed.
# Original image cleaned_cleaned_IMG_5434-23.JPG removed.
# Original image cleaned_cleaned_IMG_5431.JPG removed.
# Original image cleaned_cleaned_IMG_5447-36.JPG removed.
# Original image cleaned_cleaned_IMG_5448.JPG removed.
# Original image cleaned_cleaned_IMG_5446-35.JPG removed.
# Original image cleaned_cleaned_IMG_5451-40.JPG removed.
# Original image cleaned_cleaned_IMG_5449-38.JPG removed.
# Original image cleaned_cleaned_IMG_5448-37.JPG removed.
# Original image cleaned_cleaned_IMG_5443-32.JPG removed.
# Original image cleaned_cleaned_IMG_5452.JPG removed.
# Original image cleaned_IMG20201109095435_00.jpg removed.
# Original image cleaned_IMG20201109095439_00.jpg removed.
# Original image cleaned_IMG20201109095437_00.jpg removed.
# Original image cleaned_IMG20201109095443_00.jpg removed.
# Original image cleaned_IMG20201109095441_00.jpg removed.
# Original image cleaned_IMG20201109095449_00.jpg removed.
# Original image cleaned_IMG20201109095447_00.jpg removed.
# Original image cleaned_IMG20201109095446_00.jpg removed.
# Original image cleaned_IMG20201109095444_00.jpg removed.
# Original image cleaned_IMG20201109095640_00.jpg removed.
# Original image cleaned_IMG20201109095638_00.jpg removed.
# Original image cleaned_IMG20201109095645_00.jpg removed.
# Original image cleaned_IMG20201109095643_00.jpg removed.
# Original image cleaned_IMG20201109095650_00.jpg removed.
# Original image cleaned_IMG20201109095652_00.jpg removed.
# Original image cleaned_IMG20201109095702_00.jpg removed.
# Original image cleaned_IMG20201109095657_00.jpg removed.
# Original image cleaned_IMG20201109095654_00.jpg removed.
# Original image cleaned_IMG20201109095707_00.jpg removed.
# Original image cleaned_IMG20201109095706_00.jpg removed.
# Original image cleaned_IMG20201109095712_00.jpg removed.
# Original image cleaned_IMG20201109095709_00.jpg removed.
# Original image cleaned_IMG20201109095718_00.jpg removed.
# Original image cleaned_IMG20201109095720_00.jpg removed.
# Original image cleaned_IMG20201109095716_00.jpg removed.
# Original image cleaned_IMG20201109095713_00.jpg removed.
# Original image cleaned_IMG20201109095721_00.jpg removed.
# Original image cleaned_IMG20201109095722_00.jpg removed.
# Original image cleaned_IMG20201109095725_00.jpg removed.
# Original image cleaned_IMG20201109095727_00.jpg removed.
# Original image cleaned_IMG20201109095729_00.jpg removed.
# Original image cleaned_IMG20201109095401_00.jpg removed.
# Original image cleaned_IMG20201109095411_00.jpg removed.
# Original image cleaned_IMG20201109095407_00.jpg removed.
# Original image cleaned_IMG20201109095426_00.jpg removed.
# Original image cleaned_IMG20201109095419_00.jpg removed.
# Original image cleaned_IMG20201109095423_00.jpg removed.
# Original image cleaned_IMG20201109095416_00.jpg removed.
# Original image cleaned_IMG20201109095433_00.jpg removed.
# Original image cleaned_IMG20201109095431_00.jpg removed.
# Original image cleaned_IMG20201109095429_00.jpg removed.
# Original image cleaned_IMG20201109095428_00.jpg removed.

# %%
# Splitting data into train, validation, and test sets
train_images, test_images = train_test_split(tb_df, test_size=0.15, random_state=42)
train_images, val_images = train_test_split(train_images, test_size=0.176, random_state=42)

# %%
train_images, test_images
# Out:
# (                                              filepaths   labels
#  48    /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  603   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  426   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  82    /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  1073  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  ...                                                 ...      ...
#  654   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  861   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  246   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  28    /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#  3     /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
#
#  [838 rows x 2 columns],
#                                                filepaths     labels
#  1176  /content/drive/My Drive/PaddyLeafDeficiency/Un...  Unhealthy
#  1014  /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  101   /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  439   /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  58    /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  ...                                                 ...        ...
#  560   /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  178   /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  1140  /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  88    /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#  785   /content/drive/My Drive/PaddyLeafDeficiency/ri...    Healthy
#
#  [180 rows x 2 columns])

# %%
train_images, val_images
train_images.head()
# Out:
#                                               filepaths   labels
# 48    /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 603   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 426   /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 82    /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy
# 1073  /content/drive/My Drive/PaddyLeafDeficiency/ri...  Healthy

# %%
# Data Augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)
train_datagen

# %%
# Preprocessing for validation and test
val_datagen = ImageDataGenerator(rescale=1./255.)

# Creating train, validation, and test data generators
train_data = train_datagen.flow_from_dataframe(
    dataframe=train_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)

val_data = val_datagen.flow_from_dataframe(
    dataframe=val_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)

test_data = val_datagen.flow_from_dataframe(
    dataframe=test_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)
# Out:
# Found 838 validated image filenames belonging to 2 classes.
# Found 180 validated image filenames belonging to 2 classes.
# Found 180 validated image filenames belonging to 2 classes.

# %%
# Define Residual Block
def ResidualBlock(x, filters, kernel_size=(3, 3), strides=(1, 1), downsampling=False):
    shortcut = x
    if downsampling:
        x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(x)
        shortcut = layers.Conv2D(filters, (1, 1), strides=strides)(shortcut)
    else:
        x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(x)

    x = layers.BatchNormalization()(x)  # Before activation
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Add()([x, shortcut])
    return layers.Activation('relu')(x)

# %%
import matplotlib.pyplot as plt
import os
import random

# Define paths to the nutrient image directories
nutrient_dict = {
    'Nitrogen (N)': '/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients/Nitrogen(N)',
    'Phosphorus (P)': '/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients/Phosphorus(P)',
    'Potassium (K)': '/content/drive/My Drive/PaddyLeafDeficiency/rice_plant_lacks_nutrients/Potassium(K)'
}

# Function to load images from the specified directory
def load_images(nutrient_dir, num_images=5):
    images = os.listdir(nutrient_dir)
    selected_images = random.sample(images, min(num_images, len(images)))  # Randomly select a few images
    return [os.path.join(nutrient_dir, img) for img in selected_images]

# Set up the plot for displaying images
plt.figure(figsize=(15, 10))
num_images_per_nutrient = 3  # Set the number of images to display per nutrient

for i, (nutrient, path) in enumerate(nutrient_dict.items()):
    images = load_images(path, num_images=num_images_per_nutrient)
    for j, img_path in enumerate(images):
        img = plt.imread(img_path)
        plt.subplot(len(nutrient_dict), num_images_per_nutrient, i * num_images_per_nutrient + j + 1)
        plt.imshow(img)
        plt.axis('off')  # Turn off axis
        plt.title(nutrient)

plt.tight_layout()
plt.show()

# %%
# ResNet Model
def ResNetModel(input_shape):
    inputs = layers.Input(shape=input_shape)

    # Initial Convolutional Layer
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Adding Residual Blocks
    filter_sizes = [64, 128, 256, 512]
    num_blocks = [2, 2, 2, 2]

    for i in range(len(filter_sizes)):
        for j in range(num_blocks[i]):
            downsampling = (i > 0 and j == 0)
            x = ResidualBlock(x, filters=filter_sizes[i], strides=(2, 2) if downsampling else (1, 1), downsampling=downsampling)

    # Average Pooling Layer and Flatten
    x = layers.GlobalAveragePooling2D()(x)

    # Dense Layer with Sigmoid for Binary Classification
    outputs = layers.Dense(1, activation='sigmoid')(x)

    # Creating the Model
    model = models.Model(inputs, outputs)
    return model

# %%
# Define model parameters
input_shape = (224, 224, 3)

# Build and compile model
model = ResNetModel(input_shape=input_shape)
optimizer = optimizers.SGD(learning_rate=0.001, momentum=0.9)  # Adjusted learning rate
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Define Callbacks
checkpoint = callbacks.ModelCheckpoint(
    filepath="ResNet18_model.keras",
    monitor='val_accuracy',  # Monitor validation accuracy
    verbose=1,
    save_best_only=True,
    mode='max'
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=4,
    verbose=1,
    min_lr=0.0001
)

early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True  # Increased patience
)

tensorboard = callbacks.TensorBoard(log_dir='logs')

# Training the model
history = model.fit(
    train_data,
    steps_per_epoch=train_data.samples // train_data.batch_size,
    epochs=32,  # Increased epochs
    validation_data=val_data,
    validation_steps=val_data.samples // val_data.batch_size,
    callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard]
)

# Plotting Training vs Validation Metrics
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs. Validation Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# Evaluation on Test Data
test_loss, test_acc = model.evaluate(test_data, steps=test_data.samples // test_data.batch_size)
print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")

# Saving the final model
model.save("PaddyLeafDeficiency_ResNet18_Model.h5")

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model
with open("paddy_leaf_model.tflite", "wb") as f:
    f.write(tflite_model)

# Download the .tflite model
# files.download("paddy_leaf_model.tflite")
# Out:
# Epoch 1/32
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8414 - loss: 0.3960
# Epoch 1: val_accuracy improved from -inf to 0.97727, saving model to ResNet18_model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 307s 3s/step - accuracy: 0.8424 - loss: 0.3937 - val_accuracy: 0.9773 - val_loss: 0.1640 - learning_rate: 0.0010
# Epoch 2/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 5:29 3s/step - accuracy: 1.0000 - loss: 0.0038
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_accuracy improved from 0.97727 to 1.00000, saving model to ResNet18_model.keras
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 6.3668e-04 - learning_rate: 0.0010
# Epoch 3/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9983 - loss: 0.0095
# Epoch 3: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 292s 3s/step - accuracy: 0.9983 - loss: 0.0095 - val_accuracy: 0.9773 - val_loss: 0.2697 - learning_rate: 0.0010
# Epoch 4/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 3:31 2s/step - accuracy: 1.0000 - loss: 9.2758e-04
# Epoch 4: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 9.2758e-04 - val_accuracy: 1.0000 - val_loss: 3.6181e-06 - learning_rate: 0.0010
# Epoch 5/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0050
# Epoch 5: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 279s 3s/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9773 - val_loss: 0.2318 - learning_rate: 0.0010
# Epoch 6/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 6:07 4s/step - accuracy: 1.0000 - loss: 4.7343e-04
# Epoch 6: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 1.0000 - loss: 4.7343e-04 - val_accuracy: 1.0000 - val_loss: 8.4231e-07 - learning_rate: 0.0010
# Epoch 7/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0025
# Epoch 7: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0062 - learning_rate: 0.0010
# Epoch 8/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 3:26 2s/step - accuracy: 1.0000 - loss: 3.7298e-05
# Epoch 8: val_accuracy did not improve from 1.00000
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.7298e-05 - val_accuracy: 1.0000 - val_loss: 1.4975e-07 - learning_rate: 0.0010
# Epoch 9/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 9: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 308s 3s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 1.1983e-05 - learning_rate: 1.0000e-04
# Epoch 10/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 6:41 4s/step - accuracy: 1.0000 - loss: 2.0239e-04
# Epoch 10: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 25s 206ms/step - accuracy: 1.0000 - loss: 2.0239e-04 - val_accuracy: 1.0000 - val_loss: 4.6478e-05 - learning_rate: 1.0000e-04
# Epoch 11/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9986 - loss: 0.0034
# Epoch 11: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 340s 3s/step - accuracy: 0.9986 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 1.2530e-04 - learning_rate: 1.0000e-04
# Epoch 12/32
#   1/104 ━━━━━━━━━━━━━━━━━━━━ 5:48 3s/step - accuracy: 1.0000 - loss: 4.0081e-04
# Epoch 12: val_accuracy did not improve from 1.00000
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001.
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 1.0000 - loss: 4.0081e-04 - val_accuracy: 1.0000 - val_loss: 1.5873e-05 - learning_rate: 1.0000e-04
# Epoch 13/32
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 13: val_accuracy did not improve from 1.00000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 319s 3s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 4.8834e-04 - learning_rate: 1.0000e-04
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 14s 648ms/step - accuracy: 1.0000 - loss: 0.0056
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 1.0000, Test Loss: 0.0027
# Saved artifact at '/tmp/tmpzhaznda7'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_3366')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   135079953695840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079953697424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079953696016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079953698304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079953699888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079953702880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951330368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951332480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951327024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951333888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951329136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951326848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951861888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951864528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951861184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951865936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951862416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951860656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951870864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951873152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951869808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951874560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951871040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951869280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951550944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951550416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951548656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951553408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951549008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951552176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951559392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951561680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951560624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951562736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951562384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951564320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951779792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951782432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951779088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951783840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951780320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951778560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951325616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951891824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951788768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951791056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951787712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951792464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951788944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951787184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856719824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856722464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856719120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856723872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856720352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856718592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856728800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856731088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856733200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856817248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856731616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856733024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856821120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856823408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856820064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856824816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856821296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856819536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856731440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856733728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856829744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856832032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856831504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857685600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856829920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856831328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857689472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857691760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857688416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857693168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857689648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857687888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857698096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857700384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857098416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857094896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857096304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857096656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857102288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857104576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857100880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857105984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857102464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857103872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857699152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079857698272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079951550592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856899344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856908496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856910608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856903920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856906208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856913072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856913776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856934576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856931056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856932464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856932816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856940384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079856942672: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load the saved model
model = tf.keras.models.load_model("PaddyLeafDeficiency_ResNet18_Model.h5")

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(test_data, steps=test_data.samples // test_data.batch_size)
print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")

# Predict on the test dataset
test_data.reset()  # Reset the test data generator
predictions = model.predict(test_data, steps=test_data.samples // test_data.batch_size, verbose=1)

# Convert predictions to binary labels
predicted_labels = (predictions > 0.5).astype(int)

# Get true labels from the test dataset
true_labels = test_data.labels[:len(predicted_labels)]  # Adjust the length to match predictions

# Generate confusion matrix
cm = confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['Healthy', 'Unhealthy'], yticklabels=['Healthy', 'Unhealthy'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Generate classification report
report = classification_report(true_labels, predicted_labels, target_names=['Healthy', 'Unhealthy'])
print(report)

# Test all images in the Test_Images directory
def test_all_images(directory):
    for filename in os.listdir(directory):
        if filename.endswith('.jpg') or filename.endswith('.JPG'):  # Adjust as needed for other formats
            image_path = os.path.join(directory, filename)
            img = tf.keras.preprocessing.image.load_img(image_path, target_size=(224, 224))
            img_array = tf.keras.preprocessing.image.img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array /= 255.0  # Normalize the image

            prediction = model.predict(img_array)
            label = 'Healthy' if prediction < 0.5 else 'Unhealthy'
            print(f"Image: {filename}, Prediction: {label}")
             # Display the image along with the prediction
            plt.figure()
            plt.imshow(img)
            plt.title(f"Prediction: {label}")
            plt.axis('off')  # Turn off axis
            plt.show()

# Path to your test images directory
test_images_directory = "/content/drive/My Drive/PaddyLeafDeficiency/Test_Images/"  # Update with your actual test images directory

# Test on all images in the directory
test_all_images(test_images_directory)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 648ms/step - accuracy: 1.0000 - loss: 0.0021
# Test Accuracy: 1.0000, Test Loss: 0.0038
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 15s 644ms/step
#               precision    recall  f1-score   support
#
#      Healthy       0.97      0.97      0.97       171
#    Unhealthy       0.00      0.00      0.00         5
#
#     accuracy                           0.94       176
#    macro avg       0.49      0.49      0.49       176
# weighted avg       0.94      0.94      0.94       176
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# Image: testy.JPG, Prediction: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# Image: untitled-440.JPG, Prediction: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Image: mistake.JPG, Prediction: Unhealthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# Image: IMG20201109095638_00.JPG, Prediction: Unhealthy

# %%
# Split data into train, validation, and test sets
train_images, temp_images = train_test_split(tb_df, test_size=0.2, stratify=tb_df['labels'], random_state=42)
val_images, test_images = train_test_split(temp_images, test_size=0.5, stratify=temp_images['labels'], random_state=42)

# %%
# Data Augmentation and Preprocessing for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    horizontal_flip=True,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    fill_mode='nearest'
)

# %%
# Preprocessing for validation and test
val_datagen = ImageDataGenerator(rescale=1./255.)

# Creating train, validation, and test data generators
train_data = train_datagen.flow_from_dataframe(
    dataframe=train_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)

val_data = val_datagen.flow_from_dataframe(
    dataframe=val_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)

test_data = val_datagen.flow_from_dataframe(
    dataframe=test_images, x_col="filepaths", y_col="labels",
    batch_size=8, target_size=(224, 224), class_mode="binary"
)
# Out:
# Found 958 validated image filenames belonging to 2 classes.
# Found 120 validated image filenames belonging to 2 classes.
# Found 120 validated image filenames belonging to 2 classes.

# %%
# VGG16 Model with Pre-trained Weights
from tensorflow.keras.applications import VGG16

# Load the VGG16 model with pre-trained weights (ImageNet), excluding top layers
def VGG16Model(input_shape):
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

    # Freeze the layers in the base model to prevent them from training
    base_model.trainable = False

    # Adding custom layers on top of the base model
    x = layers.Flatten()(base_model.output)
    x = layers.Dense(512, activation='relu')(x)  # Adding a fully connected layer
    x = layers.Dropout(0.5)(x)  # Regularization to prevent overfitting
    outputs = layers.Dense(1, activation='sigmoid')(x)  # Binary classification layer

    # Define the new model
    model = models.Model(inputs=base_model.input, outputs=outputs)
    return model

# %%
# Define model parameters
input_shape = (224, 224, 3)

# Build and compile the model
model = VGG16Model(input_shape=input_shape)
optimizer = optimizers.Adam(learning_rate=0.0001)  # Use Adam optimizer for faster convergence
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Define Callbacks
checkpoint = callbacks.ModelCheckpoint(
    filepath="VGG16_model.keras",
    monitor='val_accuracy',  # Monitor validation accuracy
    verbose=1,
    save_best_only=True,
    mode='max'
)

# %%
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.1,
    patience=3,  # Reduce learning rate after 3 epochs of no improvement
    verbose=1,
    min_lr=0.001
)

# %%
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

tensorboard = callbacks.TensorBoard(log_dir='logs')

# %%
# Training the model
history = model.fit(
    train_data,
    steps_per_epoch=train_data.samples // train_data.batch_size,
    epochs=1,  # Decrease epochs since VGG16 is pre-trained
    validation_data=val_data,
    validation_steps=val_data.samples // val_data.batch_size,
    callbacks=[checkpoint, reduce_lr, early_stopping, tensorboard]
)
# Out:
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.9394 - loss: 0.2525
# Epoch 1: val_accuracy improved from -inf to 1.00000, saving model to VGG16_model.keras
# 119/119 ━━━━━━━━━━━━━━━━━━━━ 678s 6s/step - accuracy: 0.9397 - loss: 0.2515 - val_accuracy: 1.0000 - val_loss: 0.0034 - learning_rate: 1.0000e-04

# %%
import matplotlib.pyplot as plt

# Plotting Training vs Validation Metrics
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Check if 'accuracy' key exists in the history, some models may use 'acc' instead
    if 'accuracy' in history.history:
        accuracy_key = 'accuracy'
    else:
        accuracy_key = 'acc'

    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history[accuracy_key], label='Training Accuracy')
    plt.plot(history.history['val_' + accuracy_key], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training vs. Validation Accuracy')
    plt.legend()
    plt.grid(True)

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training vs. Validation Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# Example usage (assuming history is generated from model.fit)
plot_training_history(history)

# %%
# Evaluation on Test Data
test_loss, test_acc = model.evaluate(test_data, steps=test_data.samples // test_data.batch_size)
print(f"Test Accuracy: {test_acc:.4f}, Test Loss: {test_loss:.4f}")

# Saving the final model
model.save("PaddyLeafDeficiency_VGG16_Model.h5")

# Convert the model to TFLite format
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model
with open("paddy_leaf_model_vgg16.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 72s 5s/step - accuracy: 1.0000 - loss: 0.0032
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Accuracy: 1.0000, Test Loss: 0.0031
# Saved artifact at '/tmp/tmpupnb7r56'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_16')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   135079681665760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681705936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681710336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681710864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681713152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681711920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681714736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681716496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681714560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681718080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681717024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681719664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681718960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681717904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681708400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681739584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681737472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681741168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681740112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681742928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681737824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681744512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681743456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681746096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681745216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681750144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681751552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   135079681855680: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import os
import matplotlib.pyplot as plt

# Load the trained VGG16 model
model = load_model('PaddyLeafDeficiency_VGG16_Model.h5')

# Directory containing test images
test_images_dir = "/content/drive/My Drive/PaddyLeafDeficiency/Test_Images"
test_files = os.listdir(test_images_dir)

# Define a function to preprocess and predict on a single image
def predict_image(img_path, model):
    # Load image with target size of 224x224 (VGG16 input size)
    img = image.load_img(img_path, target_size=(224, 224))

    # Convert image to array
    img_array = image.img_to_array(img)

    # Reshape the image array to add an extra dimension (batch size)
    img_array = np.expand_dims(img_array, axis=0)

    # Normalize the image array (as per training, rescale by 1./255)
    img_array /= 255.0

    # Predict using the model
    prediction = model.predict(img_array)

    # Since it's a binary classification, we use a threshold of 0.5
    if prediction[0] < 0.5:
        return 'Healthy'
    else:
        return 'Unhealthy'

# Test the model on all images in the Test_Images directory
for test_file in test_files:
    img_path = os.path.join(test_images_dir, test_file)

    # Predict the class of the image
    prediction = predict_image(img_path, model)

    # Display the image and prediction result
    img = image.load_img(img_path)
    plt.imshow(img)
    plt.title(f"Prediction: {prediction}")
    plt.axis('off')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Assuming you have test data prepared as test_data
# ResNet model and VGG16 model already trained and saved

# Load your pre-trained models (ResNet and VGG16)
resnet_model = tf.keras.models.load_model("PaddyLeafDeficiency_ResNet18_Model.h5")
vgg16_model = tf.keras.models.load_model("PaddyLeafDeficiency_VGG16_Model.h5")

# Get the true labels (y_true) from your test dataset
y_true = test_data.classes  # Assuming test_data has .classes for true labels

# Get model predictions (convert probabilities to class labels using argmax if multi-class)
resnet_preds = resnet_model.predict(test_data)
resnet_preds = resnet_preds.argmax(axis=1)  # If it's a multi-class problem, otherwise remove this line

vgg16_preds = vgg16_model.predict(test_data)
vgg16_preds = vgg16_preds.argmax(axis=1)  # If it's a multi-class problem, otherwise remove this line

# Calculate metrics for ResNet
resnet_accuracy = accuracy_score(y_true, resnet_preds)
resnet_precision = precision_score(y_true, resnet_preds, average='weighted')  # Adjust 'average' for binary classification
resnet_recall = recall_score(y_true, resnet_preds, average='weighted')
resnet_f1 = f1_score(y_true, resnet_preds, average='weighted')

# Calculate metrics for VGG16
vgg16_accuracy = accuracy_score(y_true, vgg16_preds)
vgg16_precision = precision_score(y_true, vgg16_preds, average='weighted')
vgg16_recall = recall_score(y_true, vgg16_preds, average='weighted')
vgg16_f1 = f1_score(y_true, vgg16_preds, average='weighted')

# Display results
print("ResNet Model Metrics:")
print(f"Accuracy: {resnet_accuracy:.4f}")
print(f"Precision: {resnet_precision:.4f}")
print(f"Recall: {resnet_recall:.4f}")
print(f"F1-Score: {resnet_f1:.4f}")

# Optionally, print confusion matrix
print("\nResNet Confusion Matrix:")
print(confusion_matrix(y_true, resnet_preds))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 711ms/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 69s 5s/step
# ResNet Model Metrics:
# Accuracy: 0.9667
# Precision: 0.9344
# Recall: 0.9667
# F1-Score: 0.9503
#
# ResNet Confusion Matrix:
# [[116   0]
#  [  4   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
print("\nVGG16 Model Metrics:")
print(f"Accuracy: {vgg16_accuracy:.4f}")
print(f"Precision: {vgg16_precision:.4f}")
print(f"Recall: {vgg16_recall:.4f}")
print(f"F1-Score: {vgg16_f1:.4f}")


print("\nVGG16 Confusion Matrix:")
print(confusion_matrix(y_true, vgg16_preds))
# Out:
# VGG16 Model Metrics:
# Accuracy: 0.9667
# Precision: 0.9344
# Recall: 0.9667
# F1-Score: 0.9503
#
# VGG16 Confusion Matrix:
# [[116   0]
#  [  4   0]]

# %%
import tensorflow as tf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Load your pre-trained VGG16 model
vgg16_model = tf.keras.models.load_model("PaddyLeafDeficiency_VGG16_Model.h5")

# Assuming you have the test data prepared and true labels (y_true)
y_true = test_data.classes  # Assuming test_data has .classes for true labels

# Get model predictions (convert probabilities to class labels using argmax if multi-class)
vgg16_preds = vgg16_model.predict(test_data)
vgg16_preds = vgg16_preds.argmax(axis=1)  # If multi-class, otherwise skip this line for binary classification

# Calculate metrics for VGG16
vgg16_accuracy = accuracy_score(y_true, vgg16_preds)
vgg16_precision = precision_score(y_true, vgg16_preds, average='binary')  # Use 'binary' for two classes
vgg16_recall = recall_score(y_true, vgg16_preds, average='binary')
vgg16_f1 = f1_score(y_true, vgg16_preds, average='binary')

# Display the metrics
print("\nVGG16 Model Metrics:")
print(f"Accuracy: {vgg16_accuracy:.4f}")
print(f"Precision: {vgg16_precision:.4f}")
print(f"Recall: {vgg16_recall:.4f}")
print(f"F1-Score: {vgg16_f1:.4f}")

# Compute and print the confusion matrix
cm = confusion_matrix(y_true, vgg16_preds)
print("\nVGG16 Confusion Matrix:")
print(cm)

# Define labels for the binary classification problem (Healthy and Unhealthy)
labels = ['Healthy', 'Unhealthy']

# Visualize the confusion matrix using seaborn heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('VGG16 Confusion Matrix (Healthy vs Unhealthy)')
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 69s 5s/step
#
# VGG16 Model Metrics:
# Accuracy: 0.9667
# Precision: 0.0000
# Recall: 0.0000
# F1-Score: 0.0000
#
# VGG16 Confusion Matrix:
# [[116   0]
#  [  4   0]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
